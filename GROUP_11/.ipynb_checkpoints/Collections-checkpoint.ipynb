# %%
# !pip install pymongo
from pymongo import MongoClient
# Out:
# Requirement already satisfied: pymongo in c:\users\mafalda\anaconda3\envs\big data modelling\lib\site-packages (3.10.1)

# %%
host="rhea.isegi.unl.pt"
port="28011"
user="GROUP_11"
password="MTM0MzQ5MzI3NjY4ODM1MzQ2ODc2OTMzMjgyNjQ3NjYyNDcyNjUw"
protocol="mongodb"
client = MongoClient(f"{protocol}://{user}:{password}@{host}:{port}")

# %%
db = client.contracts
eu = db.eu

# %%
db.list_collection_names()
# Out:
# ['eu', 'cpv', 'iso_codes', 'cpv_codes']

# %%
eu.find_one()
# Out:
# {'_id': ObjectId('5e58fe88e3912091230e07a2'),
#  'ID_NOTICE_CAN': 20157,
#  'TED_NOTICE_URL': 'ted.europa.eu/udl?uri=TED:NOTICE:7-2015:TEXT:EN:HTML',
#  'YEAR': 2015,
#  'ID_TYPE': 3,
#  'DT_DISPATCH': '23-DEC-14',
#  'XSD_VERSION': 'R208.S2',
#  'CANCELLED': 0,
#  'CORRECTIONS': 0,
#  'CAE_NAME': 'European Union Agency for Law Enforcement Training (CEPOL)',
#  'CAE_ADDRESS': 'Ó utca 27.',
#  'CAE_TOWN': 'Budapest',
#  'CAE_POSTAL_CODE': 1066,
#  'CAE_GPA_ANNEX': 'A1EUN',
#  'ISO_COUNTRY_CODE': 'HU',
#  'ISO_COUNTRY_CODE_GPA': 'EU',
#  'CAE_TYPE': 5,
#  'EU_INST_CODE': 'AG',
#  'MAIN_ACTIVITY': 'Public Order and Safety',
#  'B_ON_BEHALF': 'N',
#  'TYPE_OF_CONTRACT': 'S',
#  'TAL_LOCATION_NUTS': 'HU101;HU102',
#  'B_FRA_AGREEMENT': 'Y',
#  'B_FRA_CONTRACT': 'Y',
#  'CPV': 79620000,
#  'MAIN_CPV_CODE_GPA': 796,
#  'ADDITIONAL_CPVS': '79621000---79612000---79610000---79600000---79611000',
#  'B_GPA': 'N',
#  'GPA_COVERAGE': 2,
#  'LOTS_NUMBER': 0,
#  'VALUE_EURO': 400000,
#  'VALUE_EURO_FIN_1': 400000,
#  'VALUE_EURO_FIN_2': 400000,
#  'B_EU_FUNDS': 'N',
#  'TOP_TYPE': 'OPE',
#  'OUT_OF_DIRECTIVES': 0,
#  'CRIT_CODE': 'L',
#  'CRIT_PRICE_WEIGHT': 100,
#  'B_ELECTRONIC_AUCTION': 'N',
#  'NUMBER_AWARDS': 1,
#  'ID_AWARD': 6630331,
#  'INFO_UNPUBLISHED': 'N',
#  'WIN_NAME': 'Manpower Munkaerő-Szervezési Kft',
#  'WIN_ADDRESS': 'Váci street 76.',
#  'WIN_TOWN': 'Budapest',
#  'WIN_POSTAL_CODE': 1133,
#  'WIN_COUNTRY_CODE': 'HU',
#  'CONTRACT_NUMBER': 'CEPOL/CT/2014/028',
#  'NUMBER_OFFERS': 1,
#  'AWARD_EST_VALUE_EURO': 400000,
#  'AWARD_VALUE_EURO': 400000,
#  'AWARD_VALUE_EURO_FIN_1': 400000,
#  'B_SUBCONTRACTED': 'N',
#  'DT_AWARD': '20-NOV-14',
#  'EQUAL_TOWN': True}

# %% [markdown]
# ## Precomputed collection

# %% [markdown]
# Due to the fact that, for the dashboard, only a limited set of countries was considered, as well as a limited interval of years and values, the first thing to be done was to filter the "eu" collection in order to only get the documents of interest. Also, since not all fields were used in the queries, it was decied to only project the fields that would be relevant to the problems at hand.

# %%
countries = ['NO', 'HR', 'HU', 'CH', 'CZ', 'RO', 'LV', 'GR', 'UK', 'SI', 'LT',
             'ES', 'FR', 'IE', 'SE', 'NL', 'PT', 'PL', 'DK', 'MK', 'DE', 'IT',
             'BG', 'CY', 'AT', 'LU', 'BE', 'FI', 'EE', 'SK', 'MT', 'LI', 'IS']

# %%
match = {
    '$match':{
        '$and':[{'YEAR':{'$gte':2008}},{'YEAR':{'$lte':2020}}],
        'VALUE_EURO':{'$lt':100000000},
        'ISO_COUNTRY_CODE':{'$in':countries}
    }
}

project = {
    '$project':{
        '_id':False,
        'VALUE_EURO':True,
        'NUMBER_OFFERS':True,
        'nCPV':'$CPV',
        'CPV':{'$toString':'$CPV'},
        'ISO_COUNTRY_CODE':True,
        'YEAR':True,
        'AWARD_VALUE_EURO':True,
        'DT_DISPATCH':{'$dateFromString':{'dateString':'$DT_DISPATCH'}},
        'DT_AWARD':{'$dateFromString':{'dateString':'$DT_AWARD'}},
        'B_EU_FUNDS':True,
        'CAE_NAME':True,
        'CAE_ADDRESS':True,
        'CAE_TOWN':True,
        'WIN_NAME':True,
        'ADDRESS':{'$concat':[{'$toString':'$CAE_ADDRESS'},' ',{'$toString':'$CAE_TOWN'}]},
        'PAIR':{'$concat':[{'$toString':'$CAE_NAME'},' with ',{'$toString':'$WIN_NAME'}]}
    }
}

pipeline = [match,project]

list_documents = list(eu.aggregate(pipeline))

# %%
db.eu_2.insert_many(list_documents)

# %%
db.eu_2.find_one()
# Out:
# {'_id': ObjectId('5ef10f668c20d9f6af748331'),
#  'YEAR': 2015,
#  'CAE_NAME': 'European Union Agency for Law Enforcement Training (CEPOL)',
#  'CAE_ADDRESS': 'Ó utca 27.',
#  'CAE_TOWN': 'Budapest',
#  'ISO_COUNTRY_CODE': 'HU',
#  'VALUE_EURO': 400000,
#  'B_EU_FUNDS': 'N',
#  'WIN_NAME': 'Manpower Munkaerő-Szervezési Kft',
#  'NUMBER_OFFERS': 1,
#  'AWARD_VALUE_EURO': 400000,
#  'nCPV': 79620000,
#  'CPV': '79620000',
#  'DT_DISPATCH': datetime.datetime(2014, 12, 23, 0, 0),
#  'DT_AWARD': datetime.datetime(2014, 11, 20, 0, 0),
#  'ADDRESS': 'Ó utca 27. Budapest',
#  'PAIR': 'European Union Agency for Law Enforcement Training (CEPOL) with Manpower Munkaerő-Szervezési Kft'}

# %%
db.eu_2.count_documents({})
# Out:
# 3040715

# %% [markdown]
# After creating a smaller collection, it was necessary to deal with the fact that there were CPV codes where the fisrt digit was 0 and therefore missing, leading to a miscalculation of the CPV division for some documents in the collection. In order to prevent that fact, all the problematic documents were identified and the CPV codes corrected. Then, the CPV division code was generated, in order to save time on future computations.

# %%
db.eu_2.update_many({'$expr':{'$lt':['$nCPV',10000000]}},[{'$set':{'CPV':{'$concat':['0','$CPV']}}}])

# %%
db.eu_2.update_many({},[{'$set':{'CPV_DIVISION':{'$substr':['$CPV',0,2]}}}])

# %%
db.eu_2.find_one()
# Out:
# {'_id': ObjectId('5ef10f668c20d9f6af748331'),
#  'YEAR': 2015,
#  'CAE_NAME': 'European Union Agency for Law Enforcement Training (CEPOL)',
#  'CAE_ADDRESS': 'Ó utca 27.',
#  'CAE_TOWN': 'Budapest',
#  'ISO_COUNTRY_CODE': 'HU',
#  'VALUE_EURO': 400000,
#  'B_EU_FUNDS': 'N',
#  'WIN_NAME': 'Manpower Munkaerő-Szervezési Kft',
#  'NUMBER_OFFERS': 1,
#  'AWARD_VALUE_EURO': 400000,
#  'nCPV': 79620000,
#  'CPV': '79620000',
#  'DT_DISPATCH': datetime.datetime(2014, 12, 23, 0, 0),
#  'DT_AWARD': datetime.datetime(2014, 11, 20, 0, 0),
#  'ADDRESS': 'Ó utca 27. Budapest',
#  'PAIR': 'European Union Agency for Law Enforcement Training (CEPOL) with Manpower Munkaerő-Szervezési Kft',
#  'CPV_DIVISION': '79'}

# %% [markdown]
# ## ISO Codes: UK problem

# %% [markdown]
# Since there was a inconsistency in the collections and the UK was identified differently in the "eu" and "iso_codes" collections, it was necessary to change one of them in order to guarantee that the queries would work correctly.
#
# In order to solve this problem there were two alternatives:
# 1. changing the ISO_COUNTRY_CODE field from UK to GB in the "eu" collection, and so making the documents in the "eu" collection consistent with, not only the "iso_codes" collection, but also with the proper alpha-2 codes;
# 2. changing the alpha-2 field from GB to UK in the "iso_codes" collection.
#
# The first oprion is more correct since the the actual alpha-2 code for the United Kingdom is indeed GB, but this means further changes to the code, that was prepared to recieve UK in the ISO_COUNTRY_CODE field. It also means that for any future document inserted, there needs to be a guarantee that where the ISO_COUNTRY_CODE is UK, it is changed to GB.

# %%
list(db.eu_2.find({'ISO_COUNTRY_CODE':'UK'}))
# Out:
# [{'_id': ObjectId('5ef10f668c20d9f6af74836e'),
#   'YEAR': 2009,
#   'CAE_NAME': 'RSS',
#   'CAE_ADDRESS': 'Bretten Hall, 45 Bush Road',
#   'CAE_TOWN': 'Antrim',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 380547.51,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Northern Microsystems',
#   'NUMBER_OFFERS': 6,
#   'nCPV': 42931000,
#   'CPV': '42931000',
#   'DT_DISPATCH': datetime.datetime(2008, 12, 29, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 11, 13, 0, 0),
#   'ADDRESS': 'Bretten Hall, 45 Bush Road Antrim',
#   'PAIR': 'RSS with Northern Microsystems',
#   'CPV_DIVISION': '42'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748371'),
#   'YEAR': 2009,
#   'CAE_NAME': 'Wakefield Metropolitan District Council',
#   'CAE_ADDRESS': 'Sport and Active Lifestyles, Town Hall',
#   'CAE_TOWN': 'Normanton',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 130118.75,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'XN Leisure Systems Ltd',
#   'nCPV': 72000000,
#   'CPV': '72000000',
#   'DT_DISPATCH': datetime.datetime(2008, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 12, 8, 0, 0),
#   'ADDRESS': 'Sport and Active Lifestyles, Town Hall Normanton',
#   'PAIR': 'Wakefield Metropolitan District Council with XN Leisure Systems Ltd',
#   'CPV_DIVISION': '72'},
#  {'_id': ObjectId('5ef10f668c20d9f6af7483e0'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Common Servcies Agency (Commonly known as NHS National Services Scotland)',
#   'CAE_ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent',
#   'CAE_TOWN': 'Edinburgh',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 5595449.03,
#   'WIN_NAME': 'PROACT Medical Ltd',
#   'NUMBER_OFFERS': 12,
#   'AWARD_VALUE_EURO': 5595449.03,
#   'nCPV': 33158500,
#   'CPV': '33158500',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 5, 0, 0),
#   'ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent Edinburgh',
#   'PAIR': 'Common Servcies Agency (Commonly known as NHS National Services Scotland) with PROACT Medical Ltd',
#   'CPV_DIVISION': '33'},
#  {'_id': ObjectId('5ef10f668c20d9f6af7483e1'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Common Servcies Agency (Commonly known as NHS National Services Scotland)',
#   'CAE_ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent',
#   'CAE_TOWN': 'Edinburgh',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 7460598.71,
#   'WIN_NAME': 'Marshall Products Limited.',
#   'NUMBER_OFFERS': 20,
#   'nCPV': 33140000,
#   'CPV': '33140000',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 1, 0, 0),
#   'ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent Edinburgh',
#   'PAIR': 'Common Servcies Agency (Commonly known as NHS National Services Scotland) with Marshall Products Limited.',
#   'CPV_DIVISION': '33'},
#  {'_id': ObjectId('5ef10f668c20d9f6af7483e2'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Common Servcies Agency (Commonly known as NHS National Services Scotland)',
#   'CAE_ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent',
#   'CAE_TOWN': 'Edinburgh',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 7460598.71,
#   'WIN_NAME': 'Unomedical Ltd (a ConvaTec Company).',
#   'NUMBER_OFFERS': 20,
#   'nCPV': 33140000,
#   'CPV': '33140000',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 1, 0, 0),
#   'ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent Edinburgh',
#   'PAIR': 'Common Servcies Agency (Commonly known as NHS National Services Scotland) with Unomedical Ltd (a ConvaTec Company).',
#   'CPV_DIVISION': '33'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748403'),
#   'YEAR': 2011,
#   'CAE_NAME': 'Entrust',
#   'CAE_ADDRESS': '60 Holly Walk, Leamington Spa, Warwickshire',
#   'CAE_TOWN': 'Leamington Spa',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 92178.64,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Spark Data Systems',
#   'NUMBER_OFFERS': 11,
#   'nCPV': 48614000,
#   'CPV': '48614000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 27, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 8, 6, 0, 0),
#   'ADDRESS': '60 Holly Walk, Leamington Spa, Warwickshire Leamington Spa',
#   'PAIR': 'Entrust with Spark Data Systems',
#   'CPV_DIVISION': '48'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748442'),
#   'YEAR': 2011,
#   'CAE_NAME': 'Transport Services - Lincolnshire County Council',
#   'CAE_ADDRESS': '3rd Floor, City Hall, Beaumont Fee',
#   'CAE_TOWN': 'Lincoln',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 68530.21,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Discount Cabs',
#   'NUMBER_OFFERS': 11,
#   'nCPV': 60112000,
#   'CPV': '60112000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 29, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 12, 8, 0, 0),
#   'ADDRESS': '3rd Floor, City Hall, Beaumont Fee Lincoln',
#   'PAIR': 'Transport Services - Lincolnshire County Council with Discount Cabs',
#   'CPV_DIVISION': '60'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748445'),
#   'YEAR': 2011,
#   'CAE_NAME': 'Transport Services - Lincolnshire County Council',
#   'CAE_ADDRESS': '3rd Floor, City Hall, Beaumont Fee',
#   'CAE_TOWN': 'Lincoln',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 386629.49,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Premier Cabs',
#   'NUMBER_OFFERS': 11,
#   'nCPV': 60112000,
#   'CPV': '60112000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 29, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 12, 9, 0, 0),
#   'ADDRESS': '3rd Floor, City Hall, Beaumont Fee Lincoln',
#   'PAIR': 'Transport Services - Lincolnshire County Council with Premier Cabs',
#   'CPV_DIVISION': '60'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748446'),
#   'YEAR': 2011,
#   'CAE_NAME': 'Transport Services - Lincolnshire County Council',
#   'CAE_ADDRESS': '3rd Floor, City Hall, Beaumont Fee',
#   'CAE_TOWN': 'Lincoln',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 386629.49,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Acorn Contract Hire',
#   'NUMBER_OFFERS': 3,
#   'nCPV': 60112000,
#   'CPV': '60112000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 29, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 12, 9, 0, 0),
#   'ADDRESS': '3rd Floor, City Hall, Beaumont Fee Lincoln',
#   'PAIR': 'Transport Services - Lincolnshire County Council with Acorn Contract Hire',
#   'CPV_DIVISION': '60'},
#  {'_id': ObjectId('5ef10f668c20d9f6af74846a'),
#   'YEAR': 2011,
#   'CAE_NAME': 'NHS Eastern and Coastal Kent',
#   'CAE_ADDRESS': 'Brook House, Reeves Way, John Wilson Business Park Chestfield',
#   'CAE_TOWN': 'Whitstable',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 368138.45,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Sellindge Practice Ltd.',
#   'nCPV': 85100000,
#   'CPV': '85100000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 24, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 11, 1, 0, 0),
#   'ADDRESS': 'Brook House, Reeves Way, John Wilson Business Park Chestfield Whitstable',
#   'PAIR': 'NHS Eastern and Coastal Kent with Sellindge Practice Ltd.',
#   'CPV_DIVISION': '85'},
#  {'_id': ObjectId('5ef10f668c20d9f6af74868b'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Common Servcies Agency (Commonly known as NHS National Services Scotland)',
#   'CAE_ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent',
#   'CAE_TOWN': 'Edinburgh',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 5595449.03,
#   'WIN_NAME': 'Dolby Medical Limited',
#   'NUMBER_OFFERS': 12,
#   'AWARD_VALUE_EURO': 5595449.03,
#   'nCPV': 33158500,
#   'CPV': '33158500',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 5, 0, 0),
#   'ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent Edinburgh',
#   'PAIR': 'Common Servcies Agency (Commonly known as NHS National Services Scotland) with Dolby Medical Limited',
#   'CPV_DIVISION': '33'},
#  {'_id': ObjectId('5ef10f668c20d9f6af74868c'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Common Servcies Agency (Commonly known as NHS National Services Scotland)',
#   'CAE_ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent',
#   'CAE_TOWN': 'Edinburgh',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 7460598.71,
#   'WIN_NAME': 'Smiths Medical International.',
#   'NUMBER_OFFERS': 20,
#   'nCPV': 33140000,
#   'CPV': '33140000',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 1, 0, 0),
#   'ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent Edinburgh',
#   'PAIR': 'Common Servcies Agency (Commonly known as NHS National Services Scotland) with Smiths Medical International.',
#   'CPV_DIVISION': '33'},
#  {'_id': ObjectId('5ef10f668c20d9f6af7486ad'),
#   'YEAR': 2011,
#   'CAE_NAME': 'In Business for Yorkshire and any other entity which is a part of the same group',
#   'CAE_ADDRESS': 'Yorkshire House, 6 Innovation Close, Heslington, North Yorkshire',
#   'CAE_TOWN': 'York',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 103700.97,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'G&J Seddon Limited',
#   'NUMBER_OFFERS': 23,
#   'nCPV': 45000000,
#   'CPV': '45000000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 24, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 12, 21, 0, 0),
#   'ADDRESS': 'Yorkshire House, 6 Innovation Close, Heslington, North Yorkshire York',
#   'PAIR': 'In Business for Yorkshire and any other entity which is a part of the same group with G&J Seddon Limited',
#   'CPV_DIVISION': '45'},
#  {'_id': ObjectId('5ef10f668c20d9f6af7486ae'),
#   'YEAR': 2011,
#   'CAE_NAME': 'South Tyneside NHS Foundation Trust',
#   'CAE_ADDRESS': 'South Tyneside District Hospital Harton Lane',
#   'CAE_TOWN': 'South Shields',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 211483.3,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Karl Storz Endoscopy (UK) Ltd',
#   'NUMBER_OFFERS': 6,
#   'AWARD_VALUE_EURO': 243677.7,
#   'nCPV': 33168000,
#   'CPV': '33168000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 16, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 10, 7, 0, 0),
#   'ADDRESS': 'South Tyneside District Hospital Harton Lane South Shields',
#   'PAIR': 'South Tyneside NHS Foundation Trust with Karl Storz Endoscopy (UK) Ltd',
#   'CPV_DIVISION': '33'},
#  {'_id': ObjectId('5ef10f668c20d9f6af7486f0'),
#   'YEAR': 2011,
#   'CAE_NAME': 'Transport Services - Lincolnshire County Council',
#   'CAE_ADDRESS': '3rd Floor, City Hall, Beaumont Fee',
#   'CAE_TOWN': 'Lincoln',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 68530.21,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Discount Cabs',
#   'NUMBER_OFFERS': 9,
#   'nCPV': 60112000,
#   'CPV': '60112000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 29, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 12, 8, 0, 0),
#   'ADDRESS': '3rd Floor, City Hall, Beaumont Fee Lincoln',
#   'PAIR': 'Transport Services - Lincolnshire County Council with Discount Cabs',
#   'CPV_DIVISION': '60'},
#  {'_id': ObjectId('5ef10f668c20d9f6af7486f1'),
#   'YEAR': 2011,
#   'CAE_NAME': 'Transport Services - Lincolnshire County Council',
#   'CAE_ADDRESS': '3rd Floor, City Hall, Beaumont Fee',
#   'CAE_TOWN': 'Lincoln',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 386629.49,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Acorn Contract Hire',
#   'NUMBER_OFFERS': 5,
#   'nCPV': 60112000,
#   'CPV': '60112000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 29, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 12, 9, 0, 0),
#   'ADDRESS': '3rd Floor, City Hall, Beaumont Fee Lincoln',
#   'PAIR': 'Transport Services - Lincolnshire County Council with Acorn Contract Hire',
#   'CPV_DIVISION': '60'},
#  {'_id': ObjectId('5ef10f668c20d9f6af7488ac'),
#   'YEAR': 2009,
#   'CAE_NAME': 'LAPN Ltd',
#   'CAE_ADDRESS': 'Charles House, Floor 4, 375 High Street Kensington',
#   'CAE_TOWN': 'London',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 561205.02,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'iMGROUP',
#   'NUMBER_OFFERS': 20,
#   'nCPV': 72260000,
#   'CPV': '72260000',
#   'DT_DISPATCH': datetime.datetime(2008, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 11, 11, 0, 0),
#   'ADDRESS': 'Charles House, Floor 4, 375 High Street Kensington London',
#   'PAIR': 'LAPN Ltd with iMGROUP',
#   'CPV_DIVISION': '72'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748942'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Common Servcies Agency (Commonly known as NHS National Services Scotland)',
#   'CAE_ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent',
#   'CAE_TOWN': 'Edinburgh',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 5595449.03,
#   'WIN_NAME': 'GE Healthcare Clinical Systems (UK) Ltd',
#   'NUMBER_OFFERS': 12,
#   'AWARD_VALUE_EURO': 5595449.03,
#   'nCPV': 33158500,
#   'CPV': '33158500',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 5, 0, 0),
#   'ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent Edinburgh',
#   'PAIR': 'Common Servcies Agency (Commonly known as NHS National Services Scotland) with GE Healthcare Clinical Systems (UK) Ltd',
#   'CPV_DIVISION': '33'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748943'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Common Servcies Agency (Commonly known as NHS National Services Scotland)',
#   'CAE_ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent',
#   'CAE_TOWN': 'Edinburgh',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 7460598.71,
#   'WIN_NAME': 'Flexicare Medical Limited.',
#   'NUMBER_OFFERS': 20,
#   'nCPV': 33140000,
#   'CPV': '33140000',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 1, 0, 0),
#   'ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent Edinburgh',
#   'PAIR': 'Common Servcies Agency (Commonly known as NHS National Services Scotland) with Flexicare Medical Limited.',
#   'CPV_DIVISION': '33'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748944'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Common Servcies Agency (Commonly known as NHS National Services Scotland)',
#   'CAE_ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent',
#   'CAE_TOWN': 'Edinburgh',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 7460598.71,
#   'WIN_NAME': 'Fannin (UK) Ltd.',
#   'NUMBER_OFFERS': 20,
#   'nCPV': 33140000,
#   'CPV': '33140000',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 1, 0, 0),
#   'ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent Edinburgh',
#   'PAIR': 'Common Servcies Agency (Commonly known as NHS National Services Scotland) with Fannin (UK) Ltd.',
#   'CPV_DIVISION': '33'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748968'),
#   'YEAR': 2011,
#   'CAE_NAME': 'In Business for Yorkshire and any other entity which is a part of the same group',
#   'CAE_ADDRESS': 'Yorkshire House, 6 Innovation Close, Heslington, North Yorkshire',
#   'CAE_TOWN': 'York',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 103700.97,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Jack Lunn (Construction) Ltd',
#   'NUMBER_OFFERS': 23,
#   'nCPV': 45000000,
#   'CPV': '45000000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 24, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 12, 21, 0, 0),
#   'ADDRESS': 'Yorkshire House, 6 Innovation Close, Heslington, North Yorkshire York',
#   'PAIR': 'In Business for Yorkshire and any other entity which is a part of the same group with Jack Lunn (Construction) Ltd',
#   'CPV_DIVISION': '45'},
#  {'_id': ObjectId('5ef10f668c20d9f6af74896a'),
#   'YEAR': 2011,
#   'CAE_NAME': 'In Business for Yorkshire and any other entity which is a part of the same group',
#   'CAE_ADDRESS': 'Yorkshire House, 6 Innovation Close, Heslington, North Yorkshire',
#   'CAE_TOWN': 'York',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 103700.97,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Wates Construction Limited',
#   'NUMBER_OFFERS': 23,
#   'nCPV': 45000000,
#   'CPV': '45000000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 24, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 12, 21, 0, 0),
#   'ADDRESS': 'Yorkshire House, 6 Innovation Close, Heslington, North Yorkshire York',
#   'PAIR': 'In Business for Yorkshire and any other entity which is a part of the same group with Wates Construction Limited',
#   'CPV_DIVISION': '45'},
#  {'_id': ObjectId('5ef10f668c20d9f6af7489ae'),
#   'YEAR': 2011,
#   'CAE_NAME': 'Transport Services - Lincolnshire County Council',
#   'CAE_ADDRESS': '3rd Floor, City Hall, Beaumont Fee',
#   'CAE_TOWN': 'Lincoln',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 68530.21,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'A & D Travel',
#   'NUMBER_OFFERS': 10,
#   'nCPV': 60112000,
#   'CPV': '60112000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 29, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 12, 8, 0, 0),
#   'ADDRESS': '3rd Floor, City Hall, Beaumont Fee Lincoln',
#   'PAIR': 'Transport Services - Lincolnshire County Council with A & D Travel',
#   'CPV_DIVISION': '60'},
#  {'_id': ObjectId('5ef10f668c20d9f6af7489b0'),
#   'YEAR': 2011,
#   'CAE_NAME': 'Transport Services - Lincolnshire County Council',
#   'CAE_ADDRESS': '3rd Floor, City Hall, Beaumont Fee',
#   'CAE_TOWN': 'Lincoln',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 386629.49,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'A A Taxis and Private Hire Ltd',
#   'NUMBER_OFFERS': 10,
#   'nCPV': 60112000,
#   'CPV': '60112000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 29, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 12, 9, 0, 0),
#   'ADDRESS': '3rd Floor, City Hall, Beaumont Fee Lincoln',
#   'PAIR': 'Transport Services - Lincolnshire County Council with A A Taxis and Private Hire Ltd',
#   'CPV_DIVISION': '60'},
#  {'_id': ObjectId('5ef10f668c20d9f6af7489b1'),
#   'YEAR': 2011,
#   'CAE_NAME': 'Transport Services - Lincolnshire County Council',
#   'CAE_ADDRESS': '3rd Floor, City Hall, Beaumont Fee',
#   'CAE_TOWN': 'Lincoln',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 386629.49,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Mr J Harlock',
#   'NUMBER_OFFERS': 9,
#   'nCPV': 60112000,
#   'CPV': '60112000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 29, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 12, 9, 0, 0),
#   'ADDRESS': '3rd Floor, City Hall, Beaumont Fee Lincoln',
#   'PAIR': 'Transport Services - Lincolnshire County Council with Mr J Harlock',
#   'CPV_DIVISION': '60'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748b8c'),
#   'YEAR': 2009,
#   'CAE_NAME': 'NHS County Durham',
#   'CAE_ADDRESS': 'John Snow House, University Science Park',
#   'CAE_TOWN': 'Durham',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 561205.02,
#   'WIN_NAME': 'County Durham & Darlington NHS Foundation Trusts',
#   'NUMBER_OFFERS': 6,
#   'nCPV': 33185100,
#   'CPV': '33185100',
#   'DT_DISPATCH': datetime.datetime(2008, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 11, 17, 0, 0),
#   'ADDRESS': 'John Snow House, University Science Park Durham',
#   'PAIR': 'NHS County Durham with County Durham & Darlington NHS Foundation Trusts',
#   'CPV_DIVISION': '33'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748ba8'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Bristol City Council',
#   'CAE_ADDRESS': 'City Development B Bond Smeaton Road',
#   'CAE_TOWN': 'Bristol',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 3485940.85,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Leadbitter & Co Ltd',
#   'AWARD_VALUE_EURO': 3485940.85,
#   'nCPV': 45453100,
#   'CPV': '45453100',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 11, 23, 0, 0),
#   'ADDRESS': 'City Development B Bond Smeaton Road Bristol',
#   'PAIR': 'Bristol City Council with Leadbitter & Co Ltd',
#   'CPV_DIVISION': '45'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748c06'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Common Servcies Agency (Commonly known as NHS National Services Scotland)',
#   'CAE_ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent',
#   'CAE_TOWN': 'Edinburgh',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 5595449.03,
#   'WIN_NAME': 'Medilink Services',
#   'NUMBER_OFFERS': 12,
#   'AWARD_VALUE_EURO': 5595449.03,
#   'nCPV': 33158500,
#   'CPV': '33158500',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 5, 0, 0),
#   'ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent Edinburgh',
#   'PAIR': 'Common Servcies Agency (Commonly known as NHS National Services Scotland) with Medilink Services',
#   'CPV_DIVISION': '33'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748c07'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Common Servcies Agency (Commonly known as NHS National Services Scotland)',
#   'CAE_ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent',
#   'CAE_TOWN': 'Edinburgh',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 7460598.71,
#   'WIN_NAME': 'Pennine Healthcare.',
#   'NUMBER_OFFERS': 20,
#   'nCPV': 33140000,
#   'CPV': '33140000',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 1, 0, 0),
#   'ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent Edinburgh',
#   'PAIR': 'Common Servcies Agency (Commonly known as NHS National Services Scotland) with Pennine Healthcare.',
#   'CPV_DIVISION': '33'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748c08'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Common Servcies Agency (Commonly known as NHS National Services Scotland)',
#   'CAE_ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent',
#   'CAE_TOWN': 'Edinburgh',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 7460598.71,
#   'WIN_NAME': 'Pall Medical',
#   'NUMBER_OFFERS': 20,
#   'nCPV': 33140000,
#   'CPV': '33140000',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 1, 0, 0),
#   'ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent Edinburgh',
#   'PAIR': 'Common Servcies Agency (Commonly known as NHS National Services Scotland) with Pall Medical',
#   'CPV_DIVISION': '33'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748c2b'),
#   'YEAR': 2011,
#   'CAE_NAME': 'In Business for Yorkshire and any other entity which is a part of the same group',
#   'CAE_ADDRESS': 'Yorkshire House, 6 Innovation Close, Heslington, North Yorkshire',
#   'CAE_TOWN': 'York',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 103700.97,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Gentoo Construction Limited',
#   'NUMBER_OFFERS': 23,
#   'nCPV': 45000000,
#   'CPV': '45000000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 24, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 12, 21, 0, 0),
#   'ADDRESS': 'Yorkshire House, 6 Innovation Close, Heslington, North Yorkshire York',
#   'PAIR': 'In Business for Yorkshire and any other entity which is a part of the same group with Gentoo Construction Limited',
#   'CPV_DIVISION': '45'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748c6e'),
#   'YEAR': 2011,
#   'CAE_NAME': 'Transport Services - Lincolnshire County Council',
#   'CAE_ADDRESS': '3rd Floor, City Hall, Beaumont Fee',
#   'CAE_TOWN': 'Lincoln',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 386629.49,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Abbey Taxis',
#   'NUMBER_OFFERS': 9,
#   'nCPV': 60112000,
#   'CPV': '60112000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 29, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 12, 9, 0, 0),
#   'ADDRESS': '3rd Floor, City Hall, Beaumont Fee Lincoln',
#   'PAIR': 'Transport Services - Lincolnshire County Council with Abbey Taxis',
#   'CPV_DIVISION': '60'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748c6f'),
#   'YEAR': 2011,
#   'CAE_NAME': 'Transport Services - Lincolnshire County Council',
#   'CAE_ADDRESS': '3rd Floor, City Hall, Beaumont Fee',
#   'CAE_TOWN': 'Lincoln',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 386629.49,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Ace Cabs',
#   'NUMBER_OFFERS': 9,
#   'nCPV': 60112000,
#   'CPV': '60112000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 29, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 12, 9, 0, 0),
#   'ADDRESS': '3rd Floor, City Hall, Beaumont Fee Lincoln',
#   'PAIR': 'Transport Services - Lincolnshire County Council with Ace Cabs',
#   'CPV_DIVISION': '60'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748e5b'),
#   'YEAR': 2010,
#   'CAE_NAME': 'London Borough of Greenwich',
#   'CAE_ADDRESS': 'Directorate of Regeneration, Enterprise & Skills, Contracts Section, Crown Building, 48 Woolwich New Road',
#   'CAE_TOWN': 'London',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 10558449.13,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Dean and Dyball Civil Engineering Ltd',
#   'NUMBER_OFFERS': 4,
#   'nCPV': 45221243,
#   'CPV': '45221243',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 11, 25, 0, 0),
#   'ADDRESS': 'Directorate of Regeneration, Enterprise & Skills, Contracts Section, Crown Building, 48 Woolwich New Road London',
#   'PAIR': 'London Borough of Greenwich with Dean and Dyball Civil Engineering Ltd',
#   'CPV_DIVISION': '45'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748eba'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Common Servcies Agency (Commonly known as NHS National Services Scotland)',
#   'CAE_ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent',
#   'CAE_TOWN': 'Edinburgh',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 5595449.03,
#   'WIN_NAME': 'Masimo UK',
#   'NUMBER_OFFERS': 12,
#   'AWARD_VALUE_EURO': 5595449.03,
#   'nCPV': 33158500,
#   'CPV': '33158500',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 5, 0, 0),
#   'ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent Edinburgh',
#   'PAIR': 'Common Servcies Agency (Commonly known as NHS National Services Scotland) with Masimo UK',
#   'CPV_DIVISION': '33'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748ebb'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Common Servcies Agency (Commonly known as NHS National Services Scotland)',
#   'CAE_ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent',
#   'CAE_TOWN': 'Edinburgh',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 7460598.71,
#   'WIN_NAME': 'Covidien UK Commercial Limited',
#   'NUMBER_OFFERS': 20,
#   'nCPV': 33140000,
#   'CPV': '33140000',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 1, 0, 0),
#   'ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent Edinburgh',
#   'PAIR': 'Common Servcies Agency (Commonly known as NHS National Services Scotland) with Covidien UK Commercial Limited',
#   'CPV_DIVISION': '33'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748ebc'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Common Servcies Agency (Commonly known as NHS National Services Scotland)',
#   'CAE_ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent',
#   'CAE_TOWN': 'Edinburgh',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 7460598.71,
#   'WIN_NAME': 'Air Safety',
#   'NUMBER_OFFERS': 20,
#   'nCPV': 33140000,
#   'CPV': '33140000',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 1, 0, 0),
#   'ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent Edinburgh',
#   'PAIR': 'Common Servcies Agency (Commonly known as NHS National Services Scotland) with Air Safety',
#   'CPV_DIVISION': '33'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748edd'),
#   'YEAR': 2011,
#   'CAE_NAME': 'In Business for Yorkshire and any other entity which is a part of the same group',
#   'CAE_ADDRESS': 'Yorkshire House, 6 Innovation Close, Heslington, North Yorkshire',
#   'CAE_TOWN': 'York',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 103700.97,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Mansell Construction Services Limited',
#   'NUMBER_OFFERS': 23,
#   'nCPV': 45000000,
#   'CPV': '45000000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 24, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 12, 21, 0, 0),
#   'ADDRESS': 'Yorkshire House, 6 Innovation Close, Heslington, North Yorkshire York',
#   'PAIR': 'In Business for Yorkshire and any other entity which is a part of the same group with Mansell Construction Services Limited',
#   'CPV_DIVISION': '45'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748ede'),
#   'YEAR': 2011,
#   'CAE_NAME': 'In Business for Yorkshire and any other entity which is a part of the same group',
#   'CAE_ADDRESS': 'Yorkshire House, 6 Innovation Close, Heslington, North Yorkshire',
#   'CAE_TOWN': 'York',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 103700.97,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Wildgoose Construction Ltd',
#   'NUMBER_OFFERS': 23,
#   'nCPV': 45000000,
#   'CPV': '45000000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 24, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 12, 21, 0, 0),
#   'ADDRESS': 'Yorkshire House, 6 Innovation Close, Heslington, North Yorkshire York',
#   'PAIR': 'In Business for Yorkshire and any other entity which is a part of the same group with Wildgoose Construction Ltd',
#   'CPV_DIVISION': '45'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748f13'),
#   'YEAR': 2011,
#   'CAE_NAME': 'Royal Wolverhampton Hospitals NHS Trust',
#   'CAE_ADDRESS': 'New Cross Hospital',
#   'CAE_TOWN': 'Wolverhampton',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 1329896.57,
#   'WIN_NAME': 'Medtronic Ltd',
#   'NUMBER_OFFERS': 5,
#   'nCPV': 33184300,
#   'CPV': '33184300',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 31, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 10, 4, 0, 0),
#   'ADDRESS': 'New Cross Hospital Wolverhampton',
#   'PAIR': 'Royal Wolverhampton Hospitals NHS Trust with Medtronic Ltd',
#   'CPV_DIVISION': '33'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748f1d'),
#   'YEAR': 2011,
#   'CAE_NAME': 'North West Leicestershire District Council',
#   'CAE_ADDRESS': 'Whitwick Road, Coalville',
#   'CAE_TOWN': 'Leicester',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 207401.94,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'CFH Total Document Control Ltd',
#   'NUMBER_OFFERS': 5,
#   'nCPV': 22000000,
#   'CPV': '22000000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 29, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 11, 16, 0, 0),
#   'ADDRESS': 'Whitwick Road, Coalville Leicester',
#   'PAIR': 'North West Leicestershire District Council with CFH Total Document Control Ltd',
#   'CPV_DIVISION': '22'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748f1e'),
#   'YEAR': 2011,
#   'CAE_NAME': 'Transport Services - Lincolnshire County Council',
#   'CAE_ADDRESS': '3rd Floor, City Hall, Beaumont Fee',
#   'CAE_TOWN': 'Lincoln',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 386629.49,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Andy Cabs',
#   'NUMBER_OFFERS': 8,
#   'nCPV': 60112000,
#   'CPV': '60112000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 29, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 12, 9, 0, 0),
#   'ADDRESS': '3rd Floor, City Hall, Beaumont Fee Lincoln',
#   'PAIR': 'Transport Services - Lincolnshire County Council with Andy Cabs',
#   'CPV_DIVISION': '60'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748f47'),
#   'YEAR': 2011,
#   'CAE_NAME': 'Bolton at Home',
#   'CAE_ADDRESS': 'Adelaide House, Adelaide Street',
#   'CAE_TOWN': 'Bolton',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 12330.68,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Safe Estates Services Ltd',
#   'NUMBER_OFFERS': 4,
#   'nCPV': 90910000,
#   'CPV': '90910000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 24, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 12, 20, 0, 0),
#   'ADDRESS': 'Adelaide House, Adelaide Street Bolton',
#   'PAIR': 'Bolton at Home with Safe Estates Services Ltd',
#   'CPV_DIVISION': '90'},
#  {'_id': ObjectId('5ef10f668c20d9f6af7490ff'),
#   'YEAR': 2009,
#   'CAE_NAME': 'NHS County Durham',
#   'CAE_ADDRESS': 'John Snow House, University Science Park',
#   'CAE_TOWN': 'Durham',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 561205.02,
#   'WIN_NAME': 'Minor Ops and David Omerod',
#   'NUMBER_OFFERS': 6,
#   'nCPV': 33185100,
#   'CPV': '33185100',
#   'DT_DISPATCH': datetime.datetime(2008, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 11, 17, 0, 0),
#   'ADDRESS': 'John Snow House, University Science Park Durham',
#   'PAIR': 'NHS County Durham with Minor Ops and David Omerod',
#   'CPV_DIVISION': '33'},
#  {'_id': ObjectId('5ef10f668c20d9f6af749103'),
#   'YEAR': 2009,
#   'CAE_NAME': 'RSS',
#   'CAE_ADDRESS': 'Bretten Hall, 45 Bush Road',
#   'CAE_TOWN': 'Antrim',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 380547.51,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Davidson & Hardy (Laboratory Supplies) Ltd',
#   'NUMBER_OFFERS': 6,
#   'nCPV': 42931000,
#   'CPV': '42931000',
#   'DT_DISPATCH': datetime.datetime(2008, 12, 29, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 11, 13, 0, 0),
#   'ADDRESS': 'Bretten Hall, 45 Bush Road Antrim',
#   'PAIR': 'RSS with Davidson & Hardy (Laboratory Supplies) Ltd',
#   'CPV_DIVISION': '42'},
#  {'_id': ObjectId('5ef10f668c20d9f6af749104'),
#   'YEAR': 2009,
#   'CAE_NAME': 'Lancashire Care NHS Foundation Trust',
#   'CAE_ADDRESS': 'Sceptre Point, Sceptre Way, Walton Summit, Bamber Bridge',
#   'CAE_TOWN': 'Preston',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 984084.23,
#   'WIN_NAME': 'Building Design Partnership Ltd',
#   'NUMBER_OFFERS': 21,
#   'AWARD_VALUE_EURO': 984084.23,
#   'nCPV': 71220000,
#   'CPV': '71220000',
#   'DT_DISPATCH': datetime.datetime(2008, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 11, 15, 0, 0),
#   'ADDRESS': 'Sceptre Point, Sceptre Way, Walton Summit, Bamber Bridge Preston',
#   'PAIR': 'Lancashire Care NHS Foundation Trust with Building Design Partnership Ltd',
#   'CPV_DIVISION': '71'},
#  {'_id': ObjectId('5ef10f668c20d9f6af74917b'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Common Servcies Agency (Commonly known as NHS National Services Scotland)',
#   'CAE_ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent',
#   'CAE_TOWN': 'Edinburgh',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 7460598.71,
#   'WIN_NAME': 'GE Healthcare Clinical Systems (UK) Ltd',
#   'NUMBER_OFFERS': 20,
#   'nCPV': 33140000,
#   'CPV': '33140000',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 1, 0, 0),
#   'ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent Edinburgh',
#   'PAIR': 'Common Servcies Agency (Commonly known as NHS National Services Scotland) with GE Healthcare Clinical Systems (UK) Ltd',
#   'CPV_DIVISION': '33'},
#  {'_id': ObjectId('5ef10f668c20d9f6af74917c'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Common Servcies Agency (Commonly known as NHS National Services Scotland)',
#   'CAE_ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent',
#   'CAE_TOWN': 'Edinburgh',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 7460598.71,
#   'WIN_NAME': 'Intersurgical Ltd.',
#   'NUMBER_OFFERS': 20,
#   'nCPV': 33140000,
#   'CPV': '33140000',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 1, 0, 0),
#   'ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent Edinburgh',
#   'PAIR': 'Common Servcies Agency (Commonly known as NHS National Services Scotland) with Intersurgical Ltd.',
#   'CPV_DIVISION': '33'},
#  {'_id': ObjectId('5ef10f668c20d9f6af74917d'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Common Servcies Agency (Commonly known as NHS National Services Scotland)',
#   'CAE_ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent',
#   'CAE_TOWN': 'Edinburgh',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 7460598.71,
#   'WIN_NAME': 'Kimberly-Clark Healthcare.',
#   'NUMBER_OFFERS': 20,
#   'nCPV': 33140000,
#   'CPV': '33140000',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 1, 0, 0),
#   'ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent Edinburgh',
#   'PAIR': 'Common Servcies Agency (Commonly known as NHS National Services Scotland) with Kimberly-Clark Healthcare.',
#   'CPV_DIVISION': '33'},
#  {'_id': ObjectId('5ef10f668c20d9f6af7491ac'),
#   'YEAR': 2011,
#   'CAE_NAME': 'In Business for Yorkshire and any other entity which is a part of the same group',
#   'CAE_ADDRESS': 'Yorkshire House, 6 Innovation Close, Heslington, North Yorkshire',
#   'CAE_TOWN': 'York',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 103700.97,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Bullock Construction Limited',
#   'NUMBER_OFFERS': 23,
#   'nCPV': 45000000,
#   'CPV': '45000000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 24, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 12, 21, 0, 0),
#   'ADDRESS': 'Yorkshire House, 6 Innovation Close, Heslington, North Yorkshire York',
#   'PAIR': 'In Business for Yorkshire and any other entity which is a part of the same group with Bullock Construction Limited',
#   'CPV_DIVISION': '45'},
#  {'_id': ObjectId('5ef10f668c20d9f6af7491f1'),
#   'YEAR': 2013,
#   'CAE_NAME': 'City and County of Swansea',
#   'CAE_ADDRESS': 'City and County of Swansea, Civic Centre',
#   'CAE_TOWN': 'Swansea',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 219014.2,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Sayers Amusements Ltd',
#   'NUMBER_OFFERS': 1,
#   'AWARD_VALUE_EURO': 219014.2,
#   'nCPV': 55520000,
#   'CPV': '55520000',
#   'DT_DISPATCH': datetime.datetime(2012, 12, 28, 0, 0),
#   'DT_AWARD': datetime.datetime(2012, 11, 7, 0, 0),
#   'ADDRESS': 'City and County of Swansea, Civic Centre Swansea',
#   'PAIR': 'City and County of Swansea with Sayers Amusements Ltd',
#   'CPV_DIVISION': '55'},
#  {'_id': ObjectId('5ef10f668c20d9f6af7491f2'),
#   'YEAR': 2013,
#   'CAE_NAME': 'City and County of Swansea',
#   'CAE_ADDRESS': 'City and County of Swansea, Civic Centre',
#   'CAE_TOWN': 'Swansea',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 219014.2,
#   'B_EU_FUNDS': 'N',
#   'nCPV': 55520000,
#   'CPV': '55520000',
#   'DT_DISPATCH': datetime.datetime(2012, 12, 28, 0, 0),
#   'DT_AWARD': None,
#   'ADDRESS': 'City and County of Swansea, Civic Centre Swansea',
#   'PAIR': None,
#   'CPV_DIVISION': '55'},
#  {'_id': ObjectId('5ef10f668c20d9f6af7491ff'),
#   'YEAR': 2011,
#   'CAE_NAME': 'Strathclyde Joint Police Board',
#   'CAE_ADDRESS': '173 Pitt Street',
#   'CAE_TOWN': 'Glasgow',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 266165.83,
#   'WIN_NAME': 'The Automobile Association Limited',
#   'NUMBER_OFFERS': 3,
#   'nCPV': 50118110,
#   'CPV': '50118110',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 29, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 11, 16, 0, 0),
#   'ADDRESS': '173 Pitt Street Glasgow',
#   'PAIR': 'Strathclyde Joint Police Board with The Automobile Association Limited',
#   'CPV_DIVISION': '50'},
#  {'_id': ObjectId('5ef10f668c20d9f6af749200'),
#   'YEAR': 2011,
#   'CAE_NAME': 'North West Leicestershire District Council',
#   'CAE_ADDRESS': 'Whitwick Road, Coalville',
#   'CAE_TOWN': 'Leicester',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 207401.94,
#   'B_EU_FUNDS': 'N',
#   'nCPV': 22000000,
#   'CPV': '22000000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 29, 0, 0),
#   'DT_AWARD': None,
#   'ADDRESS': 'Whitwick Road, Coalville Leicester',
#   'PAIR': None,
#   'CPV_DIVISION': '22'},
#  {'_id': ObjectId('5ef10f668c20d9f6af749201'),
#   'YEAR': 2011,
#   'CAE_NAME': 'Transport Services - Lincolnshire County Council',
#   'CAE_ADDRESS': '3rd Floor, City Hall, Beaumont Fee',
#   'CAE_TOWN': 'Lincoln',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 386629.49,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Ace Cabs',
#   'NUMBER_OFFERS': 13,
#   'nCPV': 60112000,
#   'CPV': '60112000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 29, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 12, 9, 0, 0),
#   'ADDRESS': '3rd Floor, City Hall, Beaumont Fee Lincoln',
#   'PAIR': 'Transport Services - Lincolnshire County Council with Ace Cabs',
#   'CPV_DIVISION': '60'},
#  {'_id': ObjectId('5ef10f668c20d9f6af749243'),
#   'YEAR': 2011,
#   'CAE_NAME': 'NHS Eastern and Coastal Kent',
#   'CAE_ADDRESS': 'Brook House, Reeves Way, John Wilson Business Park Chestfield',
#   'CAE_TOWN': 'Whitstable',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 276535.93,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Whitstable Medical Centre',
#   'nCPV': 85100000,
#   'CPV': '85100000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 24, 0, 0),
#   'DT_AWARD': None,
#   'ADDRESS': 'Brook House, Reeves Way, John Wilson Business Park Chestfield Whitstable',
#   'PAIR': 'NHS Eastern and Coastal Kent with Whitstable Medical Centre',
#   'CPV_DIVISION': '85'},
#  {'_id': ObjectId('5ef10f668c20d9f6af74949a'),
#   'YEAR': 2014,
#   'CAE_NAME': 'London Borough of Camden',
#   'CAE_ADDRESS': 'Argyle Street',
#   'CAE_TOWN': 'London',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 982785.44,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'CDL London Limited',
#   'NUMBER_OFFERS': 4,
#   'nCPV': 19640000,
#   'CPV': '19640000',
#   'DT_DISPATCH': datetime.datetime(2013, 12, 31, 0, 0),
#   'DT_AWARD': datetime.datetime(2013, 7, 2, 0, 0),
#   'ADDRESS': 'Argyle Street London',
#   'PAIR': 'London Borough of Camden with CDL London Limited',
#   'CPV_DIVISION': '19'},
#  {'_id': ObjectId('5ef10f668c20d9f6af7494c1'),
#   'YEAR': 2014,
#   'CAE_NAME': 'Business Services Organisation Procurement and Logistics Service on behalf of Western Health and Social Care (HSC) Trust',
#   'CAE_ADDRESS': 'Gransha Hospital',
#   'CAE_TOWN': 'Londonderry',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 530264.72,
#   'WIN_NAME': 'SGDD Ltd T/A Bassetts',
#   'NUMBER_OFFERS': 1,
#   'nCPV': 39715300,
#   'CPV': '39715300',
#   'DT_DISPATCH': datetime.datetime(2013, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2013, 11, 28, 0, 0),
#   'ADDRESS': 'Gransha Hospital Londonderry',
#   'PAIR': 'Business Services Organisation Procurement and Logistics Service on behalf of Western Health and Social Care (HSC) Trust with SGDD Ltd T/A Bassetts',
#   'CPV_DIVISION': '39'},
#  {'_id': ObjectId('5ef10f668c20d9f6af7494c2'),
#   'YEAR': 2014,
#   'CAE_NAME': 'Business Services Organisation Procurement and Logistics Service on behalf of Western Health and Social Care (HSC) Trust',
#   'CAE_ADDRESS': 'Gransha Hospital',
#   'CAE_TOWN': 'Londonderry',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 530264.72,
#   'WIN_NAME': 'SGDD Ltd T/A Bassetts',
#   'NUMBER_OFFERS': 1,
#   'nCPV': 39715300,
#   'CPV': '39715300',
#   'DT_DISPATCH': datetime.datetime(2013, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2013, 11, 28, 0, 0),
#   'ADDRESS': 'Gransha Hospital Londonderry',
#   'PAIR': 'Business Services Organisation Procurement and Logistics Service on behalf of Western Health and Social Care (HSC) Trust with SGDD Ltd T/A Bassetts',
#   'CPV_DIVISION': '39'},
#  {'_id': ObjectId('5ef10f668c20d9f6af7494c3'),
#   'YEAR': 2014,
#   'CAE_NAME': 'Cornwall Partnership NHS Foundation Trust',
#   'CAE_ADDRESS': 'Fairview House',
#   'CAE_TOWN': 'Bodmin',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 62025.5,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Civica UK Ltd',
#   'NUMBER_OFFERS': 3,
#   'AWARD_VALUE_EURO': 62025.5,
#   'nCPV': 48332000,
#   'CPV': '48332000',
#   'DT_DISPATCH': datetime.datetime(2013, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2013, 9, 30, 0, 0),
#   'ADDRESS': 'Fairview House Bodmin',
#   'PAIR': 'Cornwall Partnership NHS Foundation Trust with Civica UK Ltd',
#   'CPV_DIVISION': '48'},
#  {'_id': ObjectId('5ef10f668c20d9f6af7494c7'),
#   'YEAR': 2014,
#   'CAE_NAME': 'Business Services Organisation Procurement and Logistics Service on behalf of Western Health and Social Care (HSC) Trust',
#   'CAE_ADDRESS': 'Gransha Hospital',
#   'CAE_TOWN': 'Londonderry',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 530264.72,
#   'WIN_NAME': 'SGDD Ltd T/A Bassetts',
#   'NUMBER_OFFERS': 1,
#   'nCPV': 39715300,
#   'CPV': '39715300',
#   'DT_DISPATCH': datetime.datetime(2013, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2013, 11, 28, 0, 0),
#   'ADDRESS': 'Gransha Hospital Londonderry',
#   'PAIR': 'Business Services Organisation Procurement and Logistics Service on behalf of Western Health and Social Care (HSC) Trust with SGDD Ltd T/A Bassetts',
#   'CPV_DIVISION': '39'},
#  {'_id': ObjectId('5ef10f668c20d9f6af749530'),
#   'YEAR': 2014,
#   'CAE_NAME': 'Taunton and Somerset NHS Foundation Trust',
#   'CAE_ADDRESS': 'Peninsula Purchasing and Supply Alliance c/o Taunton and Somerset NHS Foundation Trust, Musgrove Park Hospital',
#   'CAE_TOWN': 'Taunton',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 310127.52,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'BOC Ltd',
#   'NUMBER_OFFERS': 2,
#   'AWARD_VALUE_EURO': 310127.52,
#   'nCPV': 24111500,
#   'CPV': '24111500',
#   'DT_DISPATCH': datetime.datetime(2013, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2013, 10, 18, 0, 0),
#   'ADDRESS': 'Peninsula Purchasing and Supply Alliance c/o Taunton and Somerset NHS Foundation Trust, Musgrove Park Hospital Taunton',
#   'PAIR': 'Taunton and Somerset NHS Foundation Trust with BOC Ltd',
#   'CPV_DIVISION': '24'},
#  {'_id': ObjectId('5ef10f668c20d9f6af749565'),
#   'YEAR': 2014,
#   'CAE_NAME': 'London Borough of Camden',
#   'CAE_ADDRESS': 'Argyle Street',
#   'CAE_TOWN': 'London',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 982785.44,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Cromwell Polythene Limited',
#   'NUMBER_OFFERS': 5,
#   'AWARD_VALUE_EURO': 534240.56,
#   'nCPV': 19640000,
#   'CPV': '19640000',
#   'DT_DISPATCH': datetime.datetime(2013, 12, 31, 0, 0),
#   'DT_AWARD': datetime.datetime(2013, 6, 11, 0, 0),
#   'ADDRESS': 'Argyle Street London',
#   'PAIR': 'London Borough of Camden with Cromwell Polythene Limited',
#   'CPV_DIVISION': '19'},
#  {'_id': ObjectId('5ef10f668c20d9f6af749592'),
#   'YEAR': 2014,
#   'CAE_NAME': 'Business Services Organisation Procurement and Logistics Service on behalf of Western Health and Social Care (HSC) Trust',
#   'CAE_ADDRESS': 'Gransha Hospital',
#   'CAE_TOWN': 'Londonderry',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 530264.72,
#   'WIN_NAME': 'SGDD Ltd T/A Bassetts',
#   'NUMBER_OFFERS': 1,
#   'nCPV': 39715300,
#   'CPV': '39715300',
#   'DT_DISPATCH': datetime.datetime(2013, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2013, 11, 28, 0, 0),
#   'ADDRESS': 'Gransha Hospital Londonderry',
#   'PAIR': 'Business Services Organisation Procurement and Logistics Service on behalf of Western Health and Social Care (HSC) Trust with SGDD Ltd T/A Bassetts',
#   'CPV_DIVISION': '39'},
#  {'_id': ObjectId('5ef10f668c20d9f6af74962d'),
#   'YEAR': 2014,
#   'CAE_NAME': 'Cornwall Partnership NHS Foundation Trust',
#   'CAE_ADDRESS': 'Fairview House',
#   'CAE_TOWN': 'Bodmin',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 77531.88,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'APT Controls Group',
#   'NUMBER_OFFERS': 2,
#   'AWARD_VALUE_EURO': 93038.26,
#   'nCPV': 31000000,
#   'CPV': '31000000',
#   'DT_DISPATCH': datetime.datetime(2013, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2013, 9, 17, 0, 0),
#   'ADDRESS': 'Fairview House Bodmin',
#   'PAIR': 'Cornwall Partnership NHS Foundation Trust with APT Controls Group',
#   'CPV_DIVISION': '31'},
#  {'_id': ObjectId('5ef10f668c20d9f6af749687'),
#   'YEAR': 2014,
#   'CAE_NAME': 'Royal Cornwall Hospitals NHS Trust',
#   'CAE_ADDRESS': 'Treliske',
#   'CAE_TOWN': 'Truro',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 434178.53,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'MJ Baker Food Service',
#   'NUMBER_OFFERS': 5,
#   'AWARD_VALUE_EURO': 124051.01,
#   'nCPV': 15000000,
#   'CPV': '15000000',
#   'DT_DISPATCH': datetime.datetime(2013, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2013, 10, 28, 0, 0),
#   'ADDRESS': 'Treliske Truro',
#   'PAIR': 'Royal Cornwall Hospitals NHS Trust with MJ Baker Food Service',
#   'CPV_DIVISION': '15'},
#  {'_id': ObjectId('5ef10f668c20d9f6af749688'),
#   'YEAR': 2014,
#   'CAE_NAME': 'Royal Cornwall Hospitals NHS Trust',
#   'CAE_ADDRESS': 'Treliske',
#   'CAE_TOWN': 'Truro',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 434178.53,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Chaffins Food Service',
#   'NUMBER_OFFERS': 5,
#   'nCPV': 15000000,
#   'CPV': '15000000',
#   'DT_DISPATCH': datetime.datetime(2013, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2013, 10, 28, 0, 0),
#   'ADDRESS': 'Treliske Truro',
#   'PAIR': 'Royal Cornwall Hospitals NHS Trust with Chaffins Food Service',
#   'CPV_DIVISION': '15'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74974c'),
#   'YEAR': 2014,
#   'CAE_NAME': "ESPO, for itself and on behalf of the 'Pro 5' Group of Professional Buying Organisations (see http://www.espo.org/about-us/collaborative-procurement.aspx)",
#   'CAE_ADDRESS': 'Barnsdale Way, Grove Park, Enderby',
#   'CAE_TOWN': 'Leicester',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 74430605.87,
#   'WIN_NAME': 'BOC Ltd (Healthcare Division) - Lot 2 award',
#   'NUMBER_OFFERS': 34,
#   'nCPV': 33195000,
#   'CPV': '33195000',
#   'DT_DISPATCH': datetime.datetime(2013, 12, 31, 0, 0),
#   'DT_AWARD': datetime.datetime(2013, 11, 21, 0, 0),
#   'ADDRESS': 'Barnsdale Way, Grove Park, Enderby Leicester',
#   'PAIR': "ESPO, for itself and on behalf of the 'Pro 5' Group of Professional Buying Organisations (see http://www.espo.org/about-us/collaborative-procurement.aspx) with BOC Ltd (Healthcare Division) - Lot 2 award",
#   'CPV_DIVISION': '33'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74974d'),
#   'YEAR': 2014,
#   'CAE_NAME': "ESPO, for itself and on behalf of the 'Pro 5' Group of Professional Buying Organisations (see http://www.espo.org/about-us/collaborative-procurement.aspx)",
#   'CAE_ADDRESS': 'Barnsdale Way, Grove Park, Enderby',
#   'CAE_TOWN': 'Leicester',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 74430605.87,
#   'WIN_NAME': 'British Telecommunications plc - Lots 1,2 & 3 Award',
#   'nCPV': 33195000,
#   'CPV': '33195000',
#   'DT_DISPATCH': datetime.datetime(2013, 12, 31, 0, 0),
#   'DT_AWARD': None,
#   'ADDRESS': 'Barnsdale Way, Grove Park, Enderby Leicester',
# ...
#   'VALUE_EURO': 6722053.06,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Creativity International Limited',
#   'nCPV': 19200000,
#   'CPV': '19200000',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 8, 0, 0),
#   'ADDRESS': '41 Industrial Park Wakefield',
#   'PAIR': 'Yorkshire Purchasing Organisation with Creativity International Limited',
#   'CPV_DIVISION': '19'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74ecb4'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Yorkshire Purchasing Organisation',
#   'CAE_ADDRESS': '41 Industrial Park',
#   'CAE_TOWN': 'Wakefield',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 6722053.06,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Debdale Colour & Chemical Company Limited',
#   'nCPV': 19200000,
#   'CPV': '19200000',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 8, 0, 0),
#   'ADDRESS': '41 Industrial Park Wakefield',
#   'PAIR': 'Yorkshire Purchasing Organisation with Debdale Colour & Chemical Company Limited',
#   'CPV_DIVISION': '19'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74ecb5'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Yorkshire Purchasing Organisation',
#   'CAE_ADDRESS': '41 Industrial Park',
#   'CAE_TOWN': 'Wakefield',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 6722053.06,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Entaco Limited',
#   'nCPV': 19200000,
#   'CPV': '19200000',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 8, 0, 0),
#   'ADDRESS': '41 Industrial Park Wakefield',
#   'PAIR': 'Yorkshire Purchasing Organisation with Entaco Limited',
#   'CPV_DIVISION': '19'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74ecb6'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Yorkshire Purchasing Organisation',
#   'CAE_ADDRESS': '41 Industrial Park',
#   'CAE_TOWN': 'Wakefield',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 6722053.06,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Fosse Polymer Products Limited',
#   'nCPV': 19200000,
#   'CPV': '19200000',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 8, 0, 0),
#   'ADDRESS': '41 Industrial Park Wakefield',
#   'PAIR': 'Yorkshire Purchasing Organisation with Fosse Polymer Products Limited',
#   'CPV_DIVISION': '19'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74ecb7'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Yorkshire Purchasing Organisation',
#   'CAE_ADDRESS': '41 Industrial Park',
#   'CAE_TOWN': 'Wakefield',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 6722053.06,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Hewitt & Booth',
#   'nCPV': 19200000,
#   'CPV': '19200000',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 8, 0, 0),
#   'ADDRESS': '41 Industrial Park Wakefield',
#   'PAIR': 'Yorkshire Purchasing Organisation with Hewitt & Booth',
#   'CPV_DIVISION': '19'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74ecb8'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Yorkshire Purchasing Organisation',
#   'CAE_ADDRESS': '41 Industrial Park',
#   'CAE_TOWN': 'Wakefield',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 6722053.06,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'J M Clayton & Co Limited',
#   'nCPV': 19200000,
#   'CPV': '19200000',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 8, 0, 0),
#   'ADDRESS': '41 Industrial Park Wakefield',
#   'PAIR': 'Yorkshire Purchasing Organisation with J M Clayton & Co Limited',
#   'CPV_DIVISION': '19'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74ecbc'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Yorkshire Purchasing Organisation',
#   'CAE_ADDRESS': '41 Industrial Park',
#   'CAE_TOWN': 'Wakefield',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 6722053.06,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'M J J',
#   'nCPV': 19200000,
#   'CPV': '19200000',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 8, 0, 0),
#   'ADDRESS': '41 Industrial Park Wakefield',
#   'PAIR': 'Yorkshire Purchasing Organisation with M J J',
#   'CPV_DIVISION': '19'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74ecbd'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Yorkshire Purchasing Organisation',
#   'CAE_ADDRESS': '41 Industrial Park',
#   'CAE_TOWN': 'Wakefield',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 6722053.06,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Major Brushes Limited',
#   'nCPV': 19200000,
#   'CPV': '19200000',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 8, 0, 0),
#   'ADDRESS': '41 Industrial Park Wakefield',
#   'PAIR': 'Yorkshire Purchasing Organisation with Major Brushes Limited',
#   'CPV_DIVISION': '19'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74ecbe'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Yorkshire Purchasing Organisation',
#   'CAE_ADDRESS': '41 Industrial Park',
#   'CAE_TOWN': 'Wakefield',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 6722053.06,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Pentel Stationery Limited',
#   'nCPV': 19200000,
#   'CPV': '19200000',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 8, 0, 0),
#   'ADDRESS': '41 Industrial Park Wakefield',
#   'PAIR': 'Yorkshire Purchasing Organisation with Pentel Stationery Limited',
#   'CPV_DIVISION': '19'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74ecbf'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Yorkshire Purchasing Organisation',
#   'CAE_ADDRESS': '41 Industrial Park',
#   'CAE_TOWN': 'Wakefield',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 6722053.06,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Slater Harrison Co Limited',
#   'nCPV': 19200000,
#   'CPV': '19200000',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 8, 0, 0),
#   'ADDRESS': '41 Industrial Park Wakefield',
#   'PAIR': 'Yorkshire Purchasing Organisation with Slater Harrison Co Limited',
#   'CPV_DIVISION': '19'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74ecc0'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Yorkshire Purchasing Organisation',
#   'CAE_ADDRESS': '41 Industrial Park',
#   'CAE_TOWN': 'Wakefield',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 6722053.06,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Specialists Crafts Limited',
#   'nCPV': 19200000,
#   'CPV': '19200000',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 8, 0, 0),
#   'ADDRESS': '41 Industrial Park Wakefield',
#   'PAIR': 'Yorkshire Purchasing Organisation with Specialists Crafts Limited',
#   'CPV_DIVISION': '19'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74ecc1'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Yorkshire Purchasing Organisation',
#   'CAE_ADDRESS': '41 Industrial Park',
#   'CAE_TOWN': 'Wakefield',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 6722053.06,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Velcro Limited',
#   'nCPV': 19200000,
#   'CPV': '19200000',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 8, 0, 0),
#   'ADDRESS': '41 Industrial Park Wakefield',
#   'PAIR': 'Yorkshire Purchasing Organisation with Velcro Limited',
#   'CPV_DIVISION': '19'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74ecc2'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Yorkshire Purchasing Organisation',
#   'CAE_ADDRESS': '41 Industrial Park',
#   'CAE_TOWN': 'Wakefield',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 477944.61,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Cicada Educational Equipment Ltd',
#   'nCPV': 39221170,
#   'CPV': '39221170',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 8, 0, 0),
#   'ADDRESS': '41 Industrial Park Wakefield',
#   'PAIR': 'Yorkshire Purchasing Organisation with Cicada Educational Equipment Ltd',
#   'CPV_DIVISION': '39'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74ecc3'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Yorkshire Purchasing Organisation',
#   'CAE_ADDRESS': '41 Industrial Park',
#   'CAE_TOWN': 'Wakefield',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 477944.61,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Craven & Co Ltd',
#   'nCPV': 39221170,
#   'CPV': '39221170',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 8, 0, 0),
#   'ADDRESS': '41 Industrial Park Wakefield',
#   'PAIR': 'Yorkshire Purchasing Organisation with Craven & Co Ltd',
#   'CPV_DIVISION': '39'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74ecc4'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Yorkshire Purchasing Organisation',
#   'CAE_ADDRESS': '41 Industrial Park',
#   'CAE_TOWN': 'Wakefield',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 477944.61,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'D&G Educational Ltd',
#   'nCPV': 39221170,
#   'CPV': '39221170',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 8, 0, 0),
#   'ADDRESS': '41 Industrial Park Wakefield',
#   'PAIR': 'Yorkshire Purchasing Organisation with D&G Educational Ltd',
#   'CPV_DIVISION': '39'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74ecc6'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Yorkshire Purchasing Organisation',
#   'CAE_ADDRESS': '41 Industrial Park',
#   'CAE_TOWN': 'Wakefield',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 6722053.06,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Spotless Punch Limited',
#   'nCPV': 19200000,
#   'CPV': '19200000',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 8, 0, 0),
#   'ADDRESS': '41 Industrial Park Wakefield',
#   'PAIR': 'Yorkshire Purchasing Organisation with Spotless Punch Limited',
#   'CPV_DIVISION': '19'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74ecc8'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Yorkshire Purchasing Organisation',
#   'CAE_ADDRESS': '41 Industrial Park',
#   'CAE_TOWN': 'Wakefield',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 6722053.06,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Vivelle (UK) Limited',
#   'nCPV': 19200000,
#   'CPV': '19200000',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 8, 0, 0),
#   'ADDRESS': '41 Industrial Park Wakefield',
#   'PAIR': 'Yorkshire Purchasing Organisation with Vivelle (UK) Limited',
#   'CPV_DIVISION': '19'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74ecc9'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Yorkshire Purchasing Organisation',
#   'CAE_ADDRESS': '41 Industrial Park',
#   'CAE_TOWN': 'Wakefield',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 6722053.06,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Victoria Grant',
#   'nCPV': 19200000,
#   'CPV': '19200000',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 8, 0, 0),
#   'ADDRESS': '41 Industrial Park Wakefield',
#   'PAIR': 'Yorkshire Purchasing Organisation with Victoria Grant',
#   'CPV_DIVISION': '19'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74ee93'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Sunderland City Council',
#   'CAE_ADDRESS': 'Corporate Procurement, PO Box 106, Civic Centre, Burden Road',
#   'CAE_TOWN': 'Sunderland',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 158766.2,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Blackpool Design Associates',
#   'NUMBER_OFFERS': 11,
#   'AWARD_VALUE_EURO': 158766.2,
#   'nCPV': 34121000,
#   'CPV': '34121000',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 7, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 10, 1, 0, 0),
#   'ADDRESS': 'Corporate Procurement, PO Box 106, Civic Centre, Burden Road Sunderland',
#   'PAIR': 'Sunderland City Council with Blackpool Design Associates',
#   'CPV_DIVISION': '34'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74eeca'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Maritime Equipment Systems, DE&S',
#   'CAE_ADDRESS': 'MES -CmrclDel1, Birch 3b, Mail Point 3327, MOD Abbey Wood South',
#   'CAE_TOWN': 'Bristol',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 1077123.94,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Burdens Ltd',
#   'NUMBER_OFFERS': 2,
#   'AWARD_VALUE_EURO': 1077123.94,
#   'nCPV': 45222100,
#   'CPV': '45222100',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 7, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 12, 30, 0, 0),
#   'ADDRESS': 'MES -CmrclDel1, Birch 3b, Mail Point 3327, MOD Abbey Wood South Bristol',
#   'PAIR': 'Maritime Equipment Systems, DE&S with Burdens Ltd',
#   'CPV_DIVISION': '45'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74ef3b'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Leicestershire County Council',
#   'CAE_ADDRESS': 'Department of Highways, Transportation and Waste Management, County Hall, Leicester Road, Glenfield',
#   'CAE_TOWN': 'Leicester',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 138149.31,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Paul S Winson Coaches Limited',
#   'NUMBER_OFFERS': 8,
#   'nCPV': 60100000,
#   'CPV': '60100000',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 6, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 12, 23, 0, 0),
#   'ADDRESS': 'Department of Highways, Transportation and Waste Management, County Hall, Leicester Road, Glenfield Leicester',
#   'PAIR': 'Leicestershire County Council with Paul S Winson Coaches Limited',
#   'CPV_DIVISION': '60'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74ef41'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Leicestershire County Council',
#   'CAE_ADDRESS': 'Department of Highways, Transportation and Waste Management, County Hall, Leicester Road, Glenfield',
#   'CAE_TOWN': 'Leicester',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 163666.88,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Paul James Coaches Limited',
#   'NUMBER_OFFERS': 4,
#   'nCPV': 60100000,
#   'CPV': '60100000',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 6, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 12, 23, 0, 0),
#   'ADDRESS': 'Department of Highways, Transportation and Waste Management, County Hall, Leicester Road, Glenfield Leicester',
#   'PAIR': 'Leicestershire County Council with Paul James Coaches Limited',
#   'CPV_DIVISION': '60'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74ef47'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Newcastle City Council',
#   'CAE_ADDRESS': 'Newcastle Civic Centre, Corporate Business Management Room 205',
#   'CAE_TOWN': 'Newcastle Upon Tyne',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 1165718.55,
#   'B_EU_FUNDS': 'Y',
#   'WIN_NAME': 'King Sturge LLP',
#   'NUMBER_OFFERS': 3,
#   'nCPV': 45111291,
#   'CPV': '45111291',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 6, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 9, 1, 0, 0),
#   'ADDRESS': 'Newcastle Civic Centre, Corporate Business Management Room 205 Newcastle Upon Tyne',
#   'PAIR': 'Newcastle City Council with King Sturge LLP',
#   'CPV_DIVISION': '45'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74ef48'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Newcastle City Council',
#   'CAE_ADDRESS': 'Newcastle Civic Centre, Corporate Business Management Room 205',
#   'CAE_TOWN': 'Newcastle Upon Tyne',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 1165718.55,
#   'B_EU_FUNDS': 'Y',
#   'WIN_NAME': 'Make Architects Ltd',
#   'NUMBER_OFFERS': 5,
#   'nCPV': 45111291,
#   'CPV': '45111291',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 6, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 9, 1, 0, 0),
#   'ADDRESS': 'Newcastle Civic Centre, Corporate Business Management Room 205 Newcastle Upon Tyne',
#   'PAIR': 'Newcastle City Council with Make Architects Ltd',
#   'CPV_DIVISION': '45'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74ef77'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Buckinghamshire County Council',
#   'CAE_ADDRESS': 'County Hall',
#   'CAE_TOWN': 'Aylesbury',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 1095775.44,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'ASM Metal Recycling Ltd',
#   'NUMBER_OFFERS': 5,
#   'AWARD_VALUE_EURO': 1095775.44,
#   'nCPV': 90000000,
#   'CPV': '90000000',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 6, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 11, 13, 0, 0),
#   'ADDRESS': 'County Hall Aylesbury',
#   'PAIR': 'Buckinghamshire County Council with ASM Metal Recycling Ltd',
#   'CPV_DIVISION': '90'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74f023'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Lewisham College',
#   'CAE_ADDRESS': 'Lewisham Way',
#   'CAE_TOWN': 'London',
#   'ISO_COUNTRY_CODE': 'UK',
#   'VALUE_EURO': 1336784.25,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'The Lewis & Graves Partnership',
#   'NUMBER_OFFERS': 12,
#   'AWARD_VALUE_EURO': 1336784.25,
#   'nCPV': 90911200,
#   'CPV': '90911200',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 7, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 12, 3, 0, 0),
#   'ADDRESS': 'Lewisham Way London',
#   'PAIR': 'Lewisham College with The Lewis & Graves Partnership',
#   'CPV_DIVISION': '90'},
#  ...]

# %%
db.eu_2.update_many({'ISO_COUNTRY_CODE':'UK'},[{'$set':{'ISO_COUNTRY_CODE':'GB'}}])

# %%
list(db.eu_2.find({'ISO_COUNTRY_CODE':'GB'}))
# Out:
# [{'_id': ObjectId('5ef10f668c20d9f6af74836e'),
#   'YEAR': 2009,
#   'CAE_NAME': 'RSS',
#   'CAE_ADDRESS': 'Bretten Hall, 45 Bush Road',
#   'CAE_TOWN': 'Antrim',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 380547.51,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Northern Microsystems',
#   'NUMBER_OFFERS': 6,
#   'nCPV': 42931000,
#   'CPV': '42931000',
#   'DT_DISPATCH': datetime.datetime(2008, 12, 29, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 11, 13, 0, 0),
#   'ADDRESS': 'Bretten Hall, 45 Bush Road Antrim',
#   'PAIR': 'RSS with Northern Microsystems',
#   'CPV_DIVISION': '42'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748371'),
#   'YEAR': 2009,
#   'CAE_NAME': 'Wakefield Metropolitan District Council',
#   'CAE_ADDRESS': 'Sport and Active Lifestyles, Town Hall',
#   'CAE_TOWN': 'Normanton',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 130118.75,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'XN Leisure Systems Ltd',
#   'nCPV': 72000000,
#   'CPV': '72000000',
#   'DT_DISPATCH': datetime.datetime(2008, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 12, 8, 0, 0),
#   'ADDRESS': 'Sport and Active Lifestyles, Town Hall Normanton',
#   'PAIR': 'Wakefield Metropolitan District Council with XN Leisure Systems Ltd',
#   'CPV_DIVISION': '72'},
#  {'_id': ObjectId('5ef10f668c20d9f6af7483e0'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Common Servcies Agency (Commonly known as NHS National Services Scotland)',
#   'CAE_ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent',
#   'CAE_TOWN': 'Edinburgh',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 5595449.03,
#   'WIN_NAME': 'PROACT Medical Ltd',
#   'NUMBER_OFFERS': 12,
#   'AWARD_VALUE_EURO': 5595449.03,
#   'nCPV': 33158500,
#   'CPV': '33158500',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 5, 0, 0),
#   'ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent Edinburgh',
#   'PAIR': 'Common Servcies Agency (Commonly known as NHS National Services Scotland) with PROACT Medical Ltd',
#   'CPV_DIVISION': '33'},
#  {'_id': ObjectId('5ef10f668c20d9f6af7483e1'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Common Servcies Agency (Commonly known as NHS National Services Scotland)',
#   'CAE_ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent',
#   'CAE_TOWN': 'Edinburgh',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 7460598.71,
#   'WIN_NAME': 'Marshall Products Limited.',
#   'NUMBER_OFFERS': 20,
#   'nCPV': 33140000,
#   'CPV': '33140000',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 1, 0, 0),
#   'ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent Edinburgh',
#   'PAIR': 'Common Servcies Agency (Commonly known as NHS National Services Scotland) with Marshall Products Limited.',
#   'CPV_DIVISION': '33'},
#  {'_id': ObjectId('5ef10f668c20d9f6af7483e2'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Common Servcies Agency (Commonly known as NHS National Services Scotland)',
#   'CAE_ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent',
#   'CAE_TOWN': 'Edinburgh',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 7460598.71,
#   'WIN_NAME': 'Unomedical Ltd (a ConvaTec Company).',
#   'NUMBER_OFFERS': 20,
#   'nCPV': 33140000,
#   'CPV': '33140000',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 1, 0, 0),
#   'ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent Edinburgh',
#   'PAIR': 'Common Servcies Agency (Commonly known as NHS National Services Scotland) with Unomedical Ltd (a ConvaTec Company).',
#   'CPV_DIVISION': '33'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748403'),
#   'YEAR': 2011,
#   'CAE_NAME': 'Entrust',
#   'CAE_ADDRESS': '60 Holly Walk, Leamington Spa, Warwickshire',
#   'CAE_TOWN': 'Leamington Spa',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 92178.64,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Spark Data Systems',
#   'NUMBER_OFFERS': 11,
#   'nCPV': 48614000,
#   'CPV': '48614000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 27, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 8, 6, 0, 0),
#   'ADDRESS': '60 Holly Walk, Leamington Spa, Warwickshire Leamington Spa',
#   'PAIR': 'Entrust with Spark Data Systems',
#   'CPV_DIVISION': '48'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748442'),
#   'YEAR': 2011,
#   'CAE_NAME': 'Transport Services - Lincolnshire County Council',
#   'CAE_ADDRESS': '3rd Floor, City Hall, Beaumont Fee',
#   'CAE_TOWN': 'Lincoln',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 68530.21,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Discount Cabs',
#   'NUMBER_OFFERS': 11,
#   'nCPV': 60112000,
#   'CPV': '60112000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 29, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 12, 8, 0, 0),
#   'ADDRESS': '3rd Floor, City Hall, Beaumont Fee Lincoln',
#   'PAIR': 'Transport Services - Lincolnshire County Council with Discount Cabs',
#   'CPV_DIVISION': '60'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748445'),
#   'YEAR': 2011,
#   'CAE_NAME': 'Transport Services - Lincolnshire County Council',
#   'CAE_ADDRESS': '3rd Floor, City Hall, Beaumont Fee',
#   'CAE_TOWN': 'Lincoln',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 386629.49,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Premier Cabs',
#   'NUMBER_OFFERS': 11,
#   'nCPV': 60112000,
#   'CPV': '60112000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 29, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 12, 9, 0, 0),
#   'ADDRESS': '3rd Floor, City Hall, Beaumont Fee Lincoln',
#   'PAIR': 'Transport Services - Lincolnshire County Council with Premier Cabs',
#   'CPV_DIVISION': '60'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748446'),
#   'YEAR': 2011,
#   'CAE_NAME': 'Transport Services - Lincolnshire County Council',
#   'CAE_ADDRESS': '3rd Floor, City Hall, Beaumont Fee',
#   'CAE_TOWN': 'Lincoln',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 386629.49,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Acorn Contract Hire',
#   'NUMBER_OFFERS': 3,
#   'nCPV': 60112000,
#   'CPV': '60112000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 29, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 12, 9, 0, 0),
#   'ADDRESS': '3rd Floor, City Hall, Beaumont Fee Lincoln',
#   'PAIR': 'Transport Services - Lincolnshire County Council with Acorn Contract Hire',
#   'CPV_DIVISION': '60'},
#  {'_id': ObjectId('5ef10f668c20d9f6af74846a'),
#   'YEAR': 2011,
#   'CAE_NAME': 'NHS Eastern and Coastal Kent',
#   'CAE_ADDRESS': 'Brook House, Reeves Way, John Wilson Business Park Chestfield',
#   'CAE_TOWN': 'Whitstable',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 368138.45,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Sellindge Practice Ltd.',
#   'nCPV': 85100000,
#   'CPV': '85100000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 24, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 11, 1, 0, 0),
#   'ADDRESS': 'Brook House, Reeves Way, John Wilson Business Park Chestfield Whitstable',
#   'PAIR': 'NHS Eastern and Coastal Kent with Sellindge Practice Ltd.',
#   'CPV_DIVISION': '85'},
#  {'_id': ObjectId('5ef10f668c20d9f6af74868b'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Common Servcies Agency (Commonly known as NHS National Services Scotland)',
#   'CAE_ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent',
#   'CAE_TOWN': 'Edinburgh',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 5595449.03,
#   'WIN_NAME': 'Dolby Medical Limited',
#   'NUMBER_OFFERS': 12,
#   'AWARD_VALUE_EURO': 5595449.03,
#   'nCPV': 33158500,
#   'CPV': '33158500',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 5, 0, 0),
#   'ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent Edinburgh',
#   'PAIR': 'Common Servcies Agency (Commonly known as NHS National Services Scotland) with Dolby Medical Limited',
#   'CPV_DIVISION': '33'},
#  {'_id': ObjectId('5ef10f668c20d9f6af74868c'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Common Servcies Agency (Commonly known as NHS National Services Scotland)',
#   'CAE_ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent',
#   'CAE_TOWN': 'Edinburgh',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 7460598.71,
#   'WIN_NAME': 'Smiths Medical International.',
#   'NUMBER_OFFERS': 20,
#   'nCPV': 33140000,
#   'CPV': '33140000',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 1, 0, 0),
#   'ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent Edinburgh',
#   'PAIR': 'Common Servcies Agency (Commonly known as NHS National Services Scotland) with Smiths Medical International.',
#   'CPV_DIVISION': '33'},
#  {'_id': ObjectId('5ef10f668c20d9f6af7486ad'),
#   'YEAR': 2011,
#   'CAE_NAME': 'In Business for Yorkshire and any other entity which is a part of the same group',
#   'CAE_ADDRESS': 'Yorkshire House, 6 Innovation Close, Heslington, North Yorkshire',
#   'CAE_TOWN': 'York',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 103700.97,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'G&J Seddon Limited',
#   'NUMBER_OFFERS': 23,
#   'nCPV': 45000000,
#   'CPV': '45000000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 24, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 12, 21, 0, 0),
#   'ADDRESS': 'Yorkshire House, 6 Innovation Close, Heslington, North Yorkshire York',
#   'PAIR': 'In Business for Yorkshire and any other entity which is a part of the same group with G&J Seddon Limited',
#   'CPV_DIVISION': '45'},
#  {'_id': ObjectId('5ef10f668c20d9f6af7486ae'),
#   'YEAR': 2011,
#   'CAE_NAME': 'South Tyneside NHS Foundation Trust',
#   'CAE_ADDRESS': 'South Tyneside District Hospital Harton Lane',
#   'CAE_TOWN': 'South Shields',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 211483.3,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Karl Storz Endoscopy (UK) Ltd',
#   'NUMBER_OFFERS': 6,
#   'AWARD_VALUE_EURO': 243677.7,
#   'nCPV': 33168000,
#   'CPV': '33168000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 16, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 10, 7, 0, 0),
#   'ADDRESS': 'South Tyneside District Hospital Harton Lane South Shields',
#   'PAIR': 'South Tyneside NHS Foundation Trust with Karl Storz Endoscopy (UK) Ltd',
#   'CPV_DIVISION': '33'},
#  {'_id': ObjectId('5ef10f668c20d9f6af7486f0'),
#   'YEAR': 2011,
#   'CAE_NAME': 'Transport Services - Lincolnshire County Council',
#   'CAE_ADDRESS': '3rd Floor, City Hall, Beaumont Fee',
#   'CAE_TOWN': 'Lincoln',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 68530.21,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Discount Cabs',
#   'NUMBER_OFFERS': 9,
#   'nCPV': 60112000,
#   'CPV': '60112000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 29, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 12, 8, 0, 0),
#   'ADDRESS': '3rd Floor, City Hall, Beaumont Fee Lincoln',
#   'PAIR': 'Transport Services - Lincolnshire County Council with Discount Cabs',
#   'CPV_DIVISION': '60'},
#  {'_id': ObjectId('5ef10f668c20d9f6af7486f1'),
#   'YEAR': 2011,
#   'CAE_NAME': 'Transport Services - Lincolnshire County Council',
#   'CAE_ADDRESS': '3rd Floor, City Hall, Beaumont Fee',
#   'CAE_TOWN': 'Lincoln',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 386629.49,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Acorn Contract Hire',
#   'NUMBER_OFFERS': 5,
#   'nCPV': 60112000,
#   'CPV': '60112000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 29, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 12, 9, 0, 0),
#   'ADDRESS': '3rd Floor, City Hall, Beaumont Fee Lincoln',
#   'PAIR': 'Transport Services - Lincolnshire County Council with Acorn Contract Hire',
#   'CPV_DIVISION': '60'},
#  {'_id': ObjectId('5ef10f668c20d9f6af7488ac'),
#   'YEAR': 2009,
#   'CAE_NAME': 'LAPN Ltd',
#   'CAE_ADDRESS': 'Charles House, Floor 4, 375 High Street Kensington',
#   'CAE_TOWN': 'London',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 561205.02,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'iMGROUP',
#   'NUMBER_OFFERS': 20,
#   'nCPV': 72260000,
#   'CPV': '72260000',
#   'DT_DISPATCH': datetime.datetime(2008, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 11, 11, 0, 0),
#   'ADDRESS': 'Charles House, Floor 4, 375 High Street Kensington London',
#   'PAIR': 'LAPN Ltd with iMGROUP',
#   'CPV_DIVISION': '72'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748942'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Common Servcies Agency (Commonly known as NHS National Services Scotland)',
#   'CAE_ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent',
#   'CAE_TOWN': 'Edinburgh',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 5595449.03,
#   'WIN_NAME': 'GE Healthcare Clinical Systems (UK) Ltd',
#   'NUMBER_OFFERS': 12,
#   'AWARD_VALUE_EURO': 5595449.03,
#   'nCPV': 33158500,
#   'CPV': '33158500',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 5, 0, 0),
#   'ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent Edinburgh',
#   'PAIR': 'Common Servcies Agency (Commonly known as NHS National Services Scotland) with GE Healthcare Clinical Systems (UK) Ltd',
#   'CPV_DIVISION': '33'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748943'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Common Servcies Agency (Commonly known as NHS National Services Scotland)',
#   'CAE_ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent',
#   'CAE_TOWN': 'Edinburgh',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 7460598.71,
#   'WIN_NAME': 'Flexicare Medical Limited.',
#   'NUMBER_OFFERS': 20,
#   'nCPV': 33140000,
#   'CPV': '33140000',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 1, 0, 0),
#   'ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent Edinburgh',
#   'PAIR': 'Common Servcies Agency (Commonly known as NHS National Services Scotland) with Flexicare Medical Limited.',
#   'CPV_DIVISION': '33'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748944'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Common Servcies Agency (Commonly known as NHS National Services Scotland)',
#   'CAE_ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent',
#   'CAE_TOWN': 'Edinburgh',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 7460598.71,
#   'WIN_NAME': 'Fannin (UK) Ltd.',
#   'NUMBER_OFFERS': 20,
#   'nCPV': 33140000,
#   'CPV': '33140000',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 1, 0, 0),
#   'ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent Edinburgh',
#   'PAIR': 'Common Servcies Agency (Commonly known as NHS National Services Scotland) with Fannin (UK) Ltd.',
#   'CPV_DIVISION': '33'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748968'),
#   'YEAR': 2011,
#   'CAE_NAME': 'In Business for Yorkshire and any other entity which is a part of the same group',
#   'CAE_ADDRESS': 'Yorkshire House, 6 Innovation Close, Heslington, North Yorkshire',
#   'CAE_TOWN': 'York',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 103700.97,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Jack Lunn (Construction) Ltd',
#   'NUMBER_OFFERS': 23,
#   'nCPV': 45000000,
#   'CPV': '45000000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 24, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 12, 21, 0, 0),
#   'ADDRESS': 'Yorkshire House, 6 Innovation Close, Heslington, North Yorkshire York',
#   'PAIR': 'In Business for Yorkshire and any other entity which is a part of the same group with Jack Lunn (Construction) Ltd',
#   'CPV_DIVISION': '45'},
#  {'_id': ObjectId('5ef10f668c20d9f6af74896a'),
#   'YEAR': 2011,
#   'CAE_NAME': 'In Business for Yorkshire and any other entity which is a part of the same group',
#   'CAE_ADDRESS': 'Yorkshire House, 6 Innovation Close, Heslington, North Yorkshire',
#   'CAE_TOWN': 'York',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 103700.97,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Wates Construction Limited',
#   'NUMBER_OFFERS': 23,
#   'nCPV': 45000000,
#   'CPV': '45000000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 24, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 12, 21, 0, 0),
#   'ADDRESS': 'Yorkshire House, 6 Innovation Close, Heslington, North Yorkshire York',
#   'PAIR': 'In Business for Yorkshire and any other entity which is a part of the same group with Wates Construction Limited',
#   'CPV_DIVISION': '45'},
#  {'_id': ObjectId('5ef10f668c20d9f6af7489ae'),
#   'YEAR': 2011,
#   'CAE_NAME': 'Transport Services - Lincolnshire County Council',
#   'CAE_ADDRESS': '3rd Floor, City Hall, Beaumont Fee',
#   'CAE_TOWN': 'Lincoln',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 68530.21,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'A & D Travel',
#   'NUMBER_OFFERS': 10,
#   'nCPV': 60112000,
#   'CPV': '60112000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 29, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 12, 8, 0, 0),
#   'ADDRESS': '3rd Floor, City Hall, Beaumont Fee Lincoln',
#   'PAIR': 'Transport Services - Lincolnshire County Council with A & D Travel',
#   'CPV_DIVISION': '60'},
#  {'_id': ObjectId('5ef10f668c20d9f6af7489b0'),
#   'YEAR': 2011,
#   'CAE_NAME': 'Transport Services - Lincolnshire County Council',
#   'CAE_ADDRESS': '3rd Floor, City Hall, Beaumont Fee',
#   'CAE_TOWN': 'Lincoln',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 386629.49,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'A A Taxis and Private Hire Ltd',
#   'NUMBER_OFFERS': 10,
#   'nCPV': 60112000,
#   'CPV': '60112000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 29, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 12, 9, 0, 0),
#   'ADDRESS': '3rd Floor, City Hall, Beaumont Fee Lincoln',
#   'PAIR': 'Transport Services - Lincolnshire County Council with A A Taxis and Private Hire Ltd',
#   'CPV_DIVISION': '60'},
#  {'_id': ObjectId('5ef10f668c20d9f6af7489b1'),
#   'YEAR': 2011,
#   'CAE_NAME': 'Transport Services - Lincolnshire County Council',
#   'CAE_ADDRESS': '3rd Floor, City Hall, Beaumont Fee',
#   'CAE_TOWN': 'Lincoln',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 386629.49,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Mr J Harlock',
#   'NUMBER_OFFERS': 9,
#   'nCPV': 60112000,
#   'CPV': '60112000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 29, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 12, 9, 0, 0),
#   'ADDRESS': '3rd Floor, City Hall, Beaumont Fee Lincoln',
#   'PAIR': 'Transport Services - Lincolnshire County Council with Mr J Harlock',
#   'CPV_DIVISION': '60'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748b8c'),
#   'YEAR': 2009,
#   'CAE_NAME': 'NHS County Durham',
#   'CAE_ADDRESS': 'John Snow House, University Science Park',
#   'CAE_TOWN': 'Durham',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 561205.02,
#   'WIN_NAME': 'County Durham & Darlington NHS Foundation Trusts',
#   'NUMBER_OFFERS': 6,
#   'nCPV': 33185100,
#   'CPV': '33185100',
#   'DT_DISPATCH': datetime.datetime(2008, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 11, 17, 0, 0),
#   'ADDRESS': 'John Snow House, University Science Park Durham',
#   'PAIR': 'NHS County Durham with County Durham & Darlington NHS Foundation Trusts',
#   'CPV_DIVISION': '33'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748ba8'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Bristol City Council',
#   'CAE_ADDRESS': 'City Development B Bond Smeaton Road',
#   'CAE_TOWN': 'Bristol',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 3485940.85,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Leadbitter & Co Ltd',
#   'AWARD_VALUE_EURO': 3485940.85,
#   'nCPV': 45453100,
#   'CPV': '45453100',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 11, 23, 0, 0),
#   'ADDRESS': 'City Development B Bond Smeaton Road Bristol',
#   'PAIR': 'Bristol City Council with Leadbitter & Co Ltd',
#   'CPV_DIVISION': '45'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748c06'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Common Servcies Agency (Commonly known as NHS National Services Scotland)',
#   'CAE_ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent',
#   'CAE_TOWN': 'Edinburgh',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 5595449.03,
#   'WIN_NAME': 'Medilink Services',
#   'NUMBER_OFFERS': 12,
#   'AWARD_VALUE_EURO': 5595449.03,
#   'nCPV': 33158500,
#   'CPV': '33158500',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 5, 0, 0),
#   'ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent Edinburgh',
#   'PAIR': 'Common Servcies Agency (Commonly known as NHS National Services Scotland) with Medilink Services',
#   'CPV_DIVISION': '33'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748c07'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Common Servcies Agency (Commonly known as NHS National Services Scotland)',
#   'CAE_ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent',
#   'CAE_TOWN': 'Edinburgh',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 7460598.71,
#   'WIN_NAME': 'Pennine Healthcare.',
#   'NUMBER_OFFERS': 20,
#   'nCPV': 33140000,
#   'CPV': '33140000',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 1, 0, 0),
#   'ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent Edinburgh',
#   'PAIR': 'Common Servcies Agency (Commonly known as NHS National Services Scotland) with Pennine Healthcare.',
#   'CPV_DIVISION': '33'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748c08'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Common Servcies Agency (Commonly known as NHS National Services Scotland)',
#   'CAE_ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent',
#   'CAE_TOWN': 'Edinburgh',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 7460598.71,
#   'WIN_NAME': 'Pall Medical',
#   'NUMBER_OFFERS': 20,
#   'nCPV': 33140000,
#   'CPV': '33140000',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 1, 0, 0),
#   'ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent Edinburgh',
#   'PAIR': 'Common Servcies Agency (Commonly known as NHS National Services Scotland) with Pall Medical',
#   'CPV_DIVISION': '33'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748c2b'),
#   'YEAR': 2011,
#   'CAE_NAME': 'In Business for Yorkshire and any other entity which is a part of the same group',
#   'CAE_ADDRESS': 'Yorkshire House, 6 Innovation Close, Heslington, North Yorkshire',
#   'CAE_TOWN': 'York',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 103700.97,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Gentoo Construction Limited',
#   'NUMBER_OFFERS': 23,
#   'nCPV': 45000000,
#   'CPV': '45000000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 24, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 12, 21, 0, 0),
#   'ADDRESS': 'Yorkshire House, 6 Innovation Close, Heslington, North Yorkshire York',
#   'PAIR': 'In Business for Yorkshire and any other entity which is a part of the same group with Gentoo Construction Limited',
#   'CPV_DIVISION': '45'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748c6e'),
#   'YEAR': 2011,
#   'CAE_NAME': 'Transport Services - Lincolnshire County Council',
#   'CAE_ADDRESS': '3rd Floor, City Hall, Beaumont Fee',
#   'CAE_TOWN': 'Lincoln',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 386629.49,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Abbey Taxis',
#   'NUMBER_OFFERS': 9,
#   'nCPV': 60112000,
#   'CPV': '60112000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 29, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 12, 9, 0, 0),
#   'ADDRESS': '3rd Floor, City Hall, Beaumont Fee Lincoln',
#   'PAIR': 'Transport Services - Lincolnshire County Council with Abbey Taxis',
#   'CPV_DIVISION': '60'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748c6f'),
#   'YEAR': 2011,
#   'CAE_NAME': 'Transport Services - Lincolnshire County Council',
#   'CAE_ADDRESS': '3rd Floor, City Hall, Beaumont Fee',
#   'CAE_TOWN': 'Lincoln',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 386629.49,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Ace Cabs',
#   'NUMBER_OFFERS': 9,
#   'nCPV': 60112000,
#   'CPV': '60112000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 29, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 12, 9, 0, 0),
#   'ADDRESS': '3rd Floor, City Hall, Beaumont Fee Lincoln',
#   'PAIR': 'Transport Services - Lincolnshire County Council with Ace Cabs',
#   'CPV_DIVISION': '60'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748e5b'),
#   'YEAR': 2010,
#   'CAE_NAME': 'London Borough of Greenwich',
#   'CAE_ADDRESS': 'Directorate of Regeneration, Enterprise & Skills, Contracts Section, Crown Building, 48 Woolwich New Road',
#   'CAE_TOWN': 'London',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 10558449.13,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Dean and Dyball Civil Engineering Ltd',
#   'NUMBER_OFFERS': 4,
#   'nCPV': 45221243,
#   'CPV': '45221243',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 11, 25, 0, 0),
#   'ADDRESS': 'Directorate of Regeneration, Enterprise & Skills, Contracts Section, Crown Building, 48 Woolwich New Road London',
#   'PAIR': 'London Borough of Greenwich with Dean and Dyball Civil Engineering Ltd',
#   'CPV_DIVISION': '45'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748eba'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Common Servcies Agency (Commonly known as NHS National Services Scotland)',
#   'CAE_ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent',
#   'CAE_TOWN': 'Edinburgh',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 5595449.03,
#   'WIN_NAME': 'Masimo UK',
#   'NUMBER_OFFERS': 12,
#   'AWARD_VALUE_EURO': 5595449.03,
#   'nCPV': 33158500,
#   'CPV': '33158500',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 5, 0, 0),
#   'ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent Edinburgh',
#   'PAIR': 'Common Servcies Agency (Commonly known as NHS National Services Scotland) with Masimo UK',
#   'CPV_DIVISION': '33'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748ebb'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Common Servcies Agency (Commonly known as NHS National Services Scotland)',
#   'CAE_ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent',
#   'CAE_TOWN': 'Edinburgh',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 7460598.71,
#   'WIN_NAME': 'Covidien UK Commercial Limited',
#   'NUMBER_OFFERS': 20,
#   'nCPV': 33140000,
#   'CPV': '33140000',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 1, 0, 0),
#   'ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent Edinburgh',
#   'PAIR': 'Common Servcies Agency (Commonly known as NHS National Services Scotland) with Covidien UK Commercial Limited',
#   'CPV_DIVISION': '33'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748ebc'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Common Servcies Agency (Commonly known as NHS National Services Scotland)',
#   'CAE_ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent',
#   'CAE_TOWN': 'Edinburgh',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 7460598.71,
#   'WIN_NAME': 'Air Safety',
#   'NUMBER_OFFERS': 20,
#   'nCPV': 33140000,
#   'CPV': '33140000',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 1, 0, 0),
#   'ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent Edinburgh',
#   'PAIR': 'Common Servcies Agency (Commonly known as NHS National Services Scotland) with Air Safety',
#   'CPV_DIVISION': '33'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748edd'),
#   'YEAR': 2011,
#   'CAE_NAME': 'In Business for Yorkshire and any other entity which is a part of the same group',
#   'CAE_ADDRESS': 'Yorkshire House, 6 Innovation Close, Heslington, North Yorkshire',
#   'CAE_TOWN': 'York',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 103700.97,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Mansell Construction Services Limited',
#   'NUMBER_OFFERS': 23,
#   'nCPV': 45000000,
#   'CPV': '45000000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 24, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 12, 21, 0, 0),
#   'ADDRESS': 'Yorkshire House, 6 Innovation Close, Heslington, North Yorkshire York',
#   'PAIR': 'In Business for Yorkshire and any other entity which is a part of the same group with Mansell Construction Services Limited',
#   'CPV_DIVISION': '45'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748ede'),
#   'YEAR': 2011,
#   'CAE_NAME': 'In Business for Yorkshire and any other entity which is a part of the same group',
#   'CAE_ADDRESS': 'Yorkshire House, 6 Innovation Close, Heslington, North Yorkshire',
#   'CAE_TOWN': 'York',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 103700.97,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Wildgoose Construction Ltd',
#   'NUMBER_OFFERS': 23,
#   'nCPV': 45000000,
#   'CPV': '45000000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 24, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 12, 21, 0, 0),
#   'ADDRESS': 'Yorkshire House, 6 Innovation Close, Heslington, North Yorkshire York',
#   'PAIR': 'In Business for Yorkshire and any other entity which is a part of the same group with Wildgoose Construction Ltd',
#   'CPV_DIVISION': '45'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748f13'),
#   'YEAR': 2011,
#   'CAE_NAME': 'Royal Wolverhampton Hospitals NHS Trust',
#   'CAE_ADDRESS': 'New Cross Hospital',
#   'CAE_TOWN': 'Wolverhampton',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 1329896.57,
#   'WIN_NAME': 'Medtronic Ltd',
#   'NUMBER_OFFERS': 5,
#   'nCPV': 33184300,
#   'CPV': '33184300',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 31, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 10, 4, 0, 0),
#   'ADDRESS': 'New Cross Hospital Wolverhampton',
#   'PAIR': 'Royal Wolverhampton Hospitals NHS Trust with Medtronic Ltd',
#   'CPV_DIVISION': '33'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748f1d'),
#   'YEAR': 2011,
#   'CAE_NAME': 'North West Leicestershire District Council',
#   'CAE_ADDRESS': 'Whitwick Road, Coalville',
#   'CAE_TOWN': 'Leicester',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 207401.94,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'CFH Total Document Control Ltd',
#   'NUMBER_OFFERS': 5,
#   'nCPV': 22000000,
#   'CPV': '22000000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 29, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 11, 16, 0, 0),
#   'ADDRESS': 'Whitwick Road, Coalville Leicester',
#   'PAIR': 'North West Leicestershire District Council with CFH Total Document Control Ltd',
#   'CPV_DIVISION': '22'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748f1e'),
#   'YEAR': 2011,
#   'CAE_NAME': 'Transport Services - Lincolnshire County Council',
#   'CAE_ADDRESS': '3rd Floor, City Hall, Beaumont Fee',
#   'CAE_TOWN': 'Lincoln',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 386629.49,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Andy Cabs',
#   'NUMBER_OFFERS': 8,
#   'nCPV': 60112000,
#   'CPV': '60112000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 29, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 12, 9, 0, 0),
#   'ADDRESS': '3rd Floor, City Hall, Beaumont Fee Lincoln',
#   'PAIR': 'Transport Services - Lincolnshire County Council with Andy Cabs',
#   'CPV_DIVISION': '60'},
#  {'_id': ObjectId('5ef10f668c20d9f6af748f47'),
#   'YEAR': 2011,
#   'CAE_NAME': 'Bolton at Home',
#   'CAE_ADDRESS': 'Adelaide House, Adelaide Street',
#   'CAE_TOWN': 'Bolton',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 12330.68,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Safe Estates Services Ltd',
#   'NUMBER_OFFERS': 4,
#   'nCPV': 90910000,
#   'CPV': '90910000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 24, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 12, 20, 0, 0),
#   'ADDRESS': 'Adelaide House, Adelaide Street Bolton',
#   'PAIR': 'Bolton at Home with Safe Estates Services Ltd',
#   'CPV_DIVISION': '90'},
#  {'_id': ObjectId('5ef10f668c20d9f6af7490ff'),
#   'YEAR': 2009,
#   'CAE_NAME': 'NHS County Durham',
#   'CAE_ADDRESS': 'John Snow House, University Science Park',
#   'CAE_TOWN': 'Durham',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 561205.02,
#   'WIN_NAME': 'Minor Ops and David Omerod',
#   'NUMBER_OFFERS': 6,
#   'nCPV': 33185100,
#   'CPV': '33185100',
#   'DT_DISPATCH': datetime.datetime(2008, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 11, 17, 0, 0),
#   'ADDRESS': 'John Snow House, University Science Park Durham',
#   'PAIR': 'NHS County Durham with Minor Ops and David Omerod',
#   'CPV_DIVISION': '33'},
#  {'_id': ObjectId('5ef10f668c20d9f6af749103'),
#   'YEAR': 2009,
#   'CAE_NAME': 'RSS',
#   'CAE_ADDRESS': 'Bretten Hall, 45 Bush Road',
#   'CAE_TOWN': 'Antrim',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 380547.51,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Davidson & Hardy (Laboratory Supplies) Ltd',
#   'NUMBER_OFFERS': 6,
#   'nCPV': 42931000,
#   'CPV': '42931000',
#   'DT_DISPATCH': datetime.datetime(2008, 12, 29, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 11, 13, 0, 0),
#   'ADDRESS': 'Bretten Hall, 45 Bush Road Antrim',
#   'PAIR': 'RSS with Davidson & Hardy (Laboratory Supplies) Ltd',
#   'CPV_DIVISION': '42'},
#  {'_id': ObjectId('5ef10f668c20d9f6af749104'),
#   'YEAR': 2009,
#   'CAE_NAME': 'Lancashire Care NHS Foundation Trust',
#   'CAE_ADDRESS': 'Sceptre Point, Sceptre Way, Walton Summit, Bamber Bridge',
#   'CAE_TOWN': 'Preston',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 984084.23,
#   'WIN_NAME': 'Building Design Partnership Ltd',
#   'NUMBER_OFFERS': 21,
#   'AWARD_VALUE_EURO': 984084.23,
#   'nCPV': 71220000,
#   'CPV': '71220000',
#   'DT_DISPATCH': datetime.datetime(2008, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 11, 15, 0, 0),
#   'ADDRESS': 'Sceptre Point, Sceptre Way, Walton Summit, Bamber Bridge Preston',
#   'PAIR': 'Lancashire Care NHS Foundation Trust with Building Design Partnership Ltd',
#   'CPV_DIVISION': '71'},
#  {'_id': ObjectId('5ef10f668c20d9f6af74917b'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Common Servcies Agency (Commonly known as NHS National Services Scotland)',
#   'CAE_ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent',
#   'CAE_TOWN': 'Edinburgh',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 7460598.71,
#   'WIN_NAME': 'GE Healthcare Clinical Systems (UK) Ltd',
#   'NUMBER_OFFERS': 20,
#   'nCPV': 33140000,
#   'CPV': '33140000',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 1, 0, 0),
#   'ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent Edinburgh',
#   'PAIR': 'Common Servcies Agency (Commonly known as NHS National Services Scotland) with GE Healthcare Clinical Systems (UK) Ltd',
#   'CPV_DIVISION': '33'},
#  {'_id': ObjectId('5ef10f668c20d9f6af74917c'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Common Servcies Agency (Commonly known as NHS National Services Scotland)',
#   'CAE_ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent',
#   'CAE_TOWN': 'Edinburgh',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 7460598.71,
#   'WIN_NAME': 'Intersurgical Ltd.',
#   'NUMBER_OFFERS': 20,
#   'nCPV': 33140000,
#   'CPV': '33140000',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 1, 0, 0),
#   'ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent Edinburgh',
#   'PAIR': 'Common Servcies Agency (Commonly known as NHS National Services Scotland) with Intersurgical Ltd.',
#   'CPV_DIVISION': '33'},
#  {'_id': ObjectId('5ef10f668c20d9f6af74917d'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Common Servcies Agency (Commonly known as NHS National Services Scotland)',
#   'CAE_ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent',
#   'CAE_TOWN': 'Edinburgh',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 7460598.71,
#   'WIN_NAME': 'Kimberly-Clark Healthcare.',
#   'NUMBER_OFFERS': 20,
#   'nCPV': 33140000,
#   'CPV': '33140000',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 1, 0, 0),
#   'ADDRESS': 'Gyle Square (NSS Head Office), 1 South Gyle Crescent Edinburgh',
#   'PAIR': 'Common Servcies Agency (Commonly known as NHS National Services Scotland) with Kimberly-Clark Healthcare.',
#   'CPV_DIVISION': '33'},
#  {'_id': ObjectId('5ef10f668c20d9f6af7491ac'),
#   'YEAR': 2011,
#   'CAE_NAME': 'In Business for Yorkshire and any other entity which is a part of the same group',
#   'CAE_ADDRESS': 'Yorkshire House, 6 Innovation Close, Heslington, North Yorkshire',
#   'CAE_TOWN': 'York',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 103700.97,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Bullock Construction Limited',
#   'NUMBER_OFFERS': 23,
#   'nCPV': 45000000,
#   'CPV': '45000000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 24, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 12, 21, 0, 0),
#   'ADDRESS': 'Yorkshire House, 6 Innovation Close, Heslington, North Yorkshire York',
#   'PAIR': 'In Business for Yorkshire and any other entity which is a part of the same group with Bullock Construction Limited',
#   'CPV_DIVISION': '45'},
#  {'_id': ObjectId('5ef10f668c20d9f6af7491f1'),
#   'YEAR': 2013,
#   'CAE_NAME': 'City and County of Swansea',
#   'CAE_ADDRESS': 'City and County of Swansea, Civic Centre',
#   'CAE_TOWN': 'Swansea',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 219014.2,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Sayers Amusements Ltd',
#   'NUMBER_OFFERS': 1,
#   'AWARD_VALUE_EURO': 219014.2,
#   'nCPV': 55520000,
#   'CPV': '55520000',
#   'DT_DISPATCH': datetime.datetime(2012, 12, 28, 0, 0),
#   'DT_AWARD': datetime.datetime(2012, 11, 7, 0, 0),
#   'ADDRESS': 'City and County of Swansea, Civic Centre Swansea',
#   'PAIR': 'City and County of Swansea with Sayers Amusements Ltd',
#   'CPV_DIVISION': '55'},
#  {'_id': ObjectId('5ef10f668c20d9f6af7491f2'),
#   'YEAR': 2013,
#   'CAE_NAME': 'City and County of Swansea',
#   'CAE_ADDRESS': 'City and County of Swansea, Civic Centre',
#   'CAE_TOWN': 'Swansea',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 219014.2,
#   'B_EU_FUNDS': 'N',
#   'nCPV': 55520000,
#   'CPV': '55520000',
#   'DT_DISPATCH': datetime.datetime(2012, 12, 28, 0, 0),
#   'DT_AWARD': None,
#   'ADDRESS': 'City and County of Swansea, Civic Centre Swansea',
#   'PAIR': None,
#   'CPV_DIVISION': '55'},
#  {'_id': ObjectId('5ef10f668c20d9f6af7491ff'),
#   'YEAR': 2011,
#   'CAE_NAME': 'Strathclyde Joint Police Board',
#   'CAE_ADDRESS': '173 Pitt Street',
#   'CAE_TOWN': 'Glasgow',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 266165.83,
#   'WIN_NAME': 'The Automobile Association Limited',
#   'NUMBER_OFFERS': 3,
#   'nCPV': 50118110,
#   'CPV': '50118110',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 29, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 11, 16, 0, 0),
#   'ADDRESS': '173 Pitt Street Glasgow',
#   'PAIR': 'Strathclyde Joint Police Board with The Automobile Association Limited',
#   'CPV_DIVISION': '50'},
#  {'_id': ObjectId('5ef10f668c20d9f6af749200'),
#   'YEAR': 2011,
#   'CAE_NAME': 'North West Leicestershire District Council',
#   'CAE_ADDRESS': 'Whitwick Road, Coalville',
#   'CAE_TOWN': 'Leicester',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 207401.94,
#   'B_EU_FUNDS': 'N',
#   'nCPV': 22000000,
#   'CPV': '22000000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 29, 0, 0),
#   'DT_AWARD': None,
#   'ADDRESS': 'Whitwick Road, Coalville Leicester',
#   'PAIR': None,
#   'CPV_DIVISION': '22'},
#  {'_id': ObjectId('5ef10f668c20d9f6af749201'),
#   'YEAR': 2011,
#   'CAE_NAME': 'Transport Services - Lincolnshire County Council',
#   'CAE_ADDRESS': '3rd Floor, City Hall, Beaumont Fee',
#   'CAE_TOWN': 'Lincoln',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 386629.49,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Ace Cabs',
#   'NUMBER_OFFERS': 13,
#   'nCPV': 60112000,
#   'CPV': '60112000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 29, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 12, 9, 0, 0),
#   'ADDRESS': '3rd Floor, City Hall, Beaumont Fee Lincoln',
#   'PAIR': 'Transport Services - Lincolnshire County Council with Ace Cabs',
#   'CPV_DIVISION': '60'},
#  {'_id': ObjectId('5ef10f668c20d9f6af749243'),
#   'YEAR': 2011,
#   'CAE_NAME': 'NHS Eastern and Coastal Kent',
#   'CAE_ADDRESS': 'Brook House, Reeves Way, John Wilson Business Park Chestfield',
#   'CAE_TOWN': 'Whitstable',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 276535.93,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Whitstable Medical Centre',
#   'nCPV': 85100000,
#   'CPV': '85100000',
#   'DT_DISPATCH': datetime.datetime(2010, 12, 24, 0, 0),
#   'DT_AWARD': None,
#   'ADDRESS': 'Brook House, Reeves Way, John Wilson Business Park Chestfield Whitstable',
#   'PAIR': 'NHS Eastern and Coastal Kent with Whitstable Medical Centre',
#   'CPV_DIVISION': '85'},
#  {'_id': ObjectId('5ef10f668c20d9f6af74949a'),
#   'YEAR': 2014,
#   'CAE_NAME': 'London Borough of Camden',
#   'CAE_ADDRESS': 'Argyle Street',
#   'CAE_TOWN': 'London',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 982785.44,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'CDL London Limited',
#   'NUMBER_OFFERS': 4,
#   'nCPV': 19640000,
#   'CPV': '19640000',
#   'DT_DISPATCH': datetime.datetime(2013, 12, 31, 0, 0),
#   'DT_AWARD': datetime.datetime(2013, 7, 2, 0, 0),
#   'ADDRESS': 'Argyle Street London',
#   'PAIR': 'London Borough of Camden with CDL London Limited',
#   'CPV_DIVISION': '19'},
#  {'_id': ObjectId('5ef10f668c20d9f6af7494c1'),
#   'YEAR': 2014,
#   'CAE_NAME': 'Business Services Organisation Procurement and Logistics Service on behalf of Western Health and Social Care (HSC) Trust',
#   'CAE_ADDRESS': 'Gransha Hospital',
#   'CAE_TOWN': 'Londonderry',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 530264.72,
#   'WIN_NAME': 'SGDD Ltd T/A Bassetts',
#   'NUMBER_OFFERS': 1,
#   'nCPV': 39715300,
#   'CPV': '39715300',
#   'DT_DISPATCH': datetime.datetime(2013, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2013, 11, 28, 0, 0),
#   'ADDRESS': 'Gransha Hospital Londonderry',
#   'PAIR': 'Business Services Organisation Procurement and Logistics Service on behalf of Western Health and Social Care (HSC) Trust with SGDD Ltd T/A Bassetts',
#   'CPV_DIVISION': '39'},
#  {'_id': ObjectId('5ef10f668c20d9f6af7494c2'),
#   'YEAR': 2014,
#   'CAE_NAME': 'Business Services Organisation Procurement and Logistics Service on behalf of Western Health and Social Care (HSC) Trust',
#   'CAE_ADDRESS': 'Gransha Hospital',
#   'CAE_TOWN': 'Londonderry',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 530264.72,
#   'WIN_NAME': 'SGDD Ltd T/A Bassetts',
#   'NUMBER_OFFERS': 1,
#   'nCPV': 39715300,
#   'CPV': '39715300',
#   'DT_DISPATCH': datetime.datetime(2013, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2013, 11, 28, 0, 0),
#   'ADDRESS': 'Gransha Hospital Londonderry',
#   'PAIR': 'Business Services Organisation Procurement and Logistics Service on behalf of Western Health and Social Care (HSC) Trust with SGDD Ltd T/A Bassetts',
#   'CPV_DIVISION': '39'},
#  {'_id': ObjectId('5ef10f668c20d9f6af7494c3'),
#   'YEAR': 2014,
#   'CAE_NAME': 'Cornwall Partnership NHS Foundation Trust',
#   'CAE_ADDRESS': 'Fairview House',
#   'CAE_TOWN': 'Bodmin',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 62025.5,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Civica UK Ltd',
#   'NUMBER_OFFERS': 3,
#   'AWARD_VALUE_EURO': 62025.5,
#   'nCPV': 48332000,
#   'CPV': '48332000',
#   'DT_DISPATCH': datetime.datetime(2013, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2013, 9, 30, 0, 0),
#   'ADDRESS': 'Fairview House Bodmin',
#   'PAIR': 'Cornwall Partnership NHS Foundation Trust with Civica UK Ltd',
#   'CPV_DIVISION': '48'},
#  {'_id': ObjectId('5ef10f668c20d9f6af7494c7'),
#   'YEAR': 2014,
#   'CAE_NAME': 'Business Services Organisation Procurement and Logistics Service on behalf of Western Health and Social Care (HSC) Trust',
#   'CAE_ADDRESS': 'Gransha Hospital',
#   'CAE_TOWN': 'Londonderry',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 530264.72,
#   'WIN_NAME': 'SGDD Ltd T/A Bassetts',
#   'NUMBER_OFFERS': 1,
#   'nCPV': 39715300,
#   'CPV': '39715300',
#   'DT_DISPATCH': datetime.datetime(2013, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2013, 11, 28, 0, 0),
#   'ADDRESS': 'Gransha Hospital Londonderry',
#   'PAIR': 'Business Services Organisation Procurement and Logistics Service on behalf of Western Health and Social Care (HSC) Trust with SGDD Ltd T/A Bassetts',
#   'CPV_DIVISION': '39'},
#  {'_id': ObjectId('5ef10f668c20d9f6af749530'),
#   'YEAR': 2014,
#   'CAE_NAME': 'Taunton and Somerset NHS Foundation Trust',
#   'CAE_ADDRESS': 'Peninsula Purchasing and Supply Alliance c/o Taunton and Somerset NHS Foundation Trust, Musgrove Park Hospital',
#   'CAE_TOWN': 'Taunton',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 310127.52,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'BOC Ltd',
#   'NUMBER_OFFERS': 2,
#   'AWARD_VALUE_EURO': 310127.52,
#   'nCPV': 24111500,
#   'CPV': '24111500',
#   'DT_DISPATCH': datetime.datetime(2013, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2013, 10, 18, 0, 0),
#   'ADDRESS': 'Peninsula Purchasing and Supply Alliance c/o Taunton and Somerset NHS Foundation Trust, Musgrove Park Hospital Taunton',
#   'PAIR': 'Taunton and Somerset NHS Foundation Trust with BOC Ltd',
#   'CPV_DIVISION': '24'},
#  {'_id': ObjectId('5ef10f668c20d9f6af749565'),
#   'YEAR': 2014,
#   'CAE_NAME': 'London Borough of Camden',
#   'CAE_ADDRESS': 'Argyle Street',
#   'CAE_TOWN': 'London',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 982785.44,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Cromwell Polythene Limited',
#   'NUMBER_OFFERS': 5,
#   'AWARD_VALUE_EURO': 534240.56,
#   'nCPV': 19640000,
#   'CPV': '19640000',
#   'DT_DISPATCH': datetime.datetime(2013, 12, 31, 0, 0),
#   'DT_AWARD': datetime.datetime(2013, 6, 11, 0, 0),
#   'ADDRESS': 'Argyle Street London',
#   'PAIR': 'London Borough of Camden with Cromwell Polythene Limited',
#   'CPV_DIVISION': '19'},
#  {'_id': ObjectId('5ef10f668c20d9f6af749592'),
#   'YEAR': 2014,
#   'CAE_NAME': 'Business Services Organisation Procurement and Logistics Service on behalf of Western Health and Social Care (HSC) Trust',
#   'CAE_ADDRESS': 'Gransha Hospital',
#   'CAE_TOWN': 'Londonderry',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 530264.72,
#   'WIN_NAME': 'SGDD Ltd T/A Bassetts',
#   'NUMBER_OFFERS': 1,
#   'nCPV': 39715300,
#   'CPV': '39715300',
#   'DT_DISPATCH': datetime.datetime(2013, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2013, 11, 28, 0, 0),
#   'ADDRESS': 'Gransha Hospital Londonderry',
#   'PAIR': 'Business Services Organisation Procurement and Logistics Service on behalf of Western Health and Social Care (HSC) Trust with SGDD Ltd T/A Bassetts',
#   'CPV_DIVISION': '39'},
#  {'_id': ObjectId('5ef10f668c20d9f6af74962d'),
#   'YEAR': 2014,
#   'CAE_NAME': 'Cornwall Partnership NHS Foundation Trust',
#   'CAE_ADDRESS': 'Fairview House',
#   'CAE_TOWN': 'Bodmin',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 77531.88,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'APT Controls Group',
#   'NUMBER_OFFERS': 2,
#   'AWARD_VALUE_EURO': 93038.26,
#   'nCPV': 31000000,
#   'CPV': '31000000',
#   'DT_DISPATCH': datetime.datetime(2013, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2013, 9, 17, 0, 0),
#   'ADDRESS': 'Fairview House Bodmin',
#   'PAIR': 'Cornwall Partnership NHS Foundation Trust with APT Controls Group',
#   'CPV_DIVISION': '31'},
#  {'_id': ObjectId('5ef10f668c20d9f6af749687'),
#   'YEAR': 2014,
#   'CAE_NAME': 'Royal Cornwall Hospitals NHS Trust',
#   'CAE_ADDRESS': 'Treliske',
#   'CAE_TOWN': 'Truro',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 434178.53,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'MJ Baker Food Service',
#   'NUMBER_OFFERS': 5,
#   'AWARD_VALUE_EURO': 124051.01,
#   'nCPV': 15000000,
#   'CPV': '15000000',
#   'DT_DISPATCH': datetime.datetime(2013, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2013, 10, 28, 0, 0),
#   'ADDRESS': 'Treliske Truro',
#   'PAIR': 'Royal Cornwall Hospitals NHS Trust with MJ Baker Food Service',
#   'CPV_DIVISION': '15'},
#  {'_id': ObjectId('5ef10f668c20d9f6af749688'),
#   'YEAR': 2014,
#   'CAE_NAME': 'Royal Cornwall Hospitals NHS Trust',
#   'CAE_ADDRESS': 'Treliske',
#   'CAE_TOWN': 'Truro',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 434178.53,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Chaffins Food Service',
#   'NUMBER_OFFERS': 5,
#   'nCPV': 15000000,
#   'CPV': '15000000',
#   'DT_DISPATCH': datetime.datetime(2013, 12, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2013, 10, 28, 0, 0),
#   'ADDRESS': 'Treliske Truro',
#   'PAIR': 'Royal Cornwall Hospitals NHS Trust with Chaffins Food Service',
#   'CPV_DIVISION': '15'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74974c'),
#   'YEAR': 2014,
#   'CAE_NAME': "ESPO, for itself and on behalf of the 'Pro 5' Group of Professional Buying Organisations (see http://www.espo.org/about-us/collaborative-procurement.aspx)",
#   'CAE_ADDRESS': 'Barnsdale Way, Grove Park, Enderby',
#   'CAE_TOWN': 'Leicester',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 74430605.87,
#   'WIN_NAME': 'BOC Ltd (Healthcare Division) - Lot 2 award',
#   'NUMBER_OFFERS': 34,
#   'nCPV': 33195000,
#   'CPV': '33195000',
#   'DT_DISPATCH': datetime.datetime(2013, 12, 31, 0, 0),
#   'DT_AWARD': datetime.datetime(2013, 11, 21, 0, 0),
#   'ADDRESS': 'Barnsdale Way, Grove Park, Enderby Leicester',
#   'PAIR': "ESPO, for itself and on behalf of the 'Pro 5' Group of Professional Buying Organisations (see http://www.espo.org/about-us/collaborative-procurement.aspx) with BOC Ltd (Healthcare Division) - Lot 2 award",
#   'CPV_DIVISION': '33'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74974d'),
#   'YEAR': 2014,
#   'CAE_NAME': "ESPO, for itself and on behalf of the 'Pro 5' Group of Professional Buying Organisations (see http://www.espo.org/about-us/collaborative-procurement.aspx)",
#   'CAE_ADDRESS': 'Barnsdale Way, Grove Park, Enderby',
#   'CAE_TOWN': 'Leicester',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 74430605.87,
#   'WIN_NAME': 'British Telecommunications plc - Lots 1,2 & 3 Award',
#   'nCPV': 33195000,
#   'CPV': '33195000',
#   'DT_DISPATCH': datetime.datetime(2013, 12, 31, 0, 0),
#   'DT_AWARD': None,
#   'ADDRESS': 'Barnsdale Way, Grove Park, Enderby Leicester',
# ...
#   'VALUE_EURO': 6722053.06,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Creativity International Limited',
#   'nCPV': 19200000,
#   'CPV': '19200000',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 8, 0, 0),
#   'ADDRESS': '41 Industrial Park Wakefield',
#   'PAIR': 'Yorkshire Purchasing Organisation with Creativity International Limited',
#   'CPV_DIVISION': '19'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74ecb4'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Yorkshire Purchasing Organisation',
#   'CAE_ADDRESS': '41 Industrial Park',
#   'CAE_TOWN': 'Wakefield',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 6722053.06,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Debdale Colour & Chemical Company Limited',
#   'nCPV': 19200000,
#   'CPV': '19200000',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 8, 0, 0),
#   'ADDRESS': '41 Industrial Park Wakefield',
#   'PAIR': 'Yorkshire Purchasing Organisation with Debdale Colour & Chemical Company Limited',
#   'CPV_DIVISION': '19'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74ecb5'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Yorkshire Purchasing Organisation',
#   'CAE_ADDRESS': '41 Industrial Park',
#   'CAE_TOWN': 'Wakefield',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 6722053.06,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Entaco Limited',
#   'nCPV': 19200000,
#   'CPV': '19200000',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 8, 0, 0),
#   'ADDRESS': '41 Industrial Park Wakefield',
#   'PAIR': 'Yorkshire Purchasing Organisation with Entaco Limited',
#   'CPV_DIVISION': '19'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74ecb6'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Yorkshire Purchasing Organisation',
#   'CAE_ADDRESS': '41 Industrial Park',
#   'CAE_TOWN': 'Wakefield',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 6722053.06,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Fosse Polymer Products Limited',
#   'nCPV': 19200000,
#   'CPV': '19200000',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 8, 0, 0),
#   'ADDRESS': '41 Industrial Park Wakefield',
#   'PAIR': 'Yorkshire Purchasing Organisation with Fosse Polymer Products Limited',
#   'CPV_DIVISION': '19'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74ecb7'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Yorkshire Purchasing Organisation',
#   'CAE_ADDRESS': '41 Industrial Park',
#   'CAE_TOWN': 'Wakefield',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 6722053.06,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Hewitt & Booth',
#   'nCPV': 19200000,
#   'CPV': '19200000',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 8, 0, 0),
#   'ADDRESS': '41 Industrial Park Wakefield',
#   'PAIR': 'Yorkshire Purchasing Organisation with Hewitt & Booth',
#   'CPV_DIVISION': '19'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74ecb8'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Yorkshire Purchasing Organisation',
#   'CAE_ADDRESS': '41 Industrial Park',
#   'CAE_TOWN': 'Wakefield',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 6722053.06,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'J M Clayton & Co Limited',
#   'nCPV': 19200000,
#   'CPV': '19200000',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 8, 0, 0),
#   'ADDRESS': '41 Industrial Park Wakefield',
#   'PAIR': 'Yorkshire Purchasing Organisation with J M Clayton & Co Limited',
#   'CPV_DIVISION': '19'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74ecbc'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Yorkshire Purchasing Organisation',
#   'CAE_ADDRESS': '41 Industrial Park',
#   'CAE_TOWN': 'Wakefield',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 6722053.06,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'M J J',
#   'nCPV': 19200000,
#   'CPV': '19200000',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 8, 0, 0),
#   'ADDRESS': '41 Industrial Park Wakefield',
#   'PAIR': 'Yorkshire Purchasing Organisation with M J J',
#   'CPV_DIVISION': '19'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74ecbd'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Yorkshire Purchasing Organisation',
#   'CAE_ADDRESS': '41 Industrial Park',
#   'CAE_TOWN': 'Wakefield',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 6722053.06,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Major Brushes Limited',
#   'nCPV': 19200000,
#   'CPV': '19200000',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 8, 0, 0),
#   'ADDRESS': '41 Industrial Park Wakefield',
#   'PAIR': 'Yorkshire Purchasing Organisation with Major Brushes Limited',
#   'CPV_DIVISION': '19'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74ecbe'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Yorkshire Purchasing Organisation',
#   'CAE_ADDRESS': '41 Industrial Park',
#   'CAE_TOWN': 'Wakefield',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 6722053.06,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Pentel Stationery Limited',
#   'nCPV': 19200000,
#   'CPV': '19200000',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 8, 0, 0),
#   'ADDRESS': '41 Industrial Park Wakefield',
#   'PAIR': 'Yorkshire Purchasing Organisation with Pentel Stationery Limited',
#   'CPV_DIVISION': '19'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74ecbf'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Yorkshire Purchasing Organisation',
#   'CAE_ADDRESS': '41 Industrial Park',
#   'CAE_TOWN': 'Wakefield',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 6722053.06,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Slater Harrison Co Limited',
#   'nCPV': 19200000,
#   'CPV': '19200000',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 8, 0, 0),
#   'ADDRESS': '41 Industrial Park Wakefield',
#   'PAIR': 'Yorkshire Purchasing Organisation with Slater Harrison Co Limited',
#   'CPV_DIVISION': '19'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74ecc0'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Yorkshire Purchasing Organisation',
#   'CAE_ADDRESS': '41 Industrial Park',
#   'CAE_TOWN': 'Wakefield',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 6722053.06,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Specialists Crafts Limited',
#   'nCPV': 19200000,
#   'CPV': '19200000',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 8, 0, 0),
#   'ADDRESS': '41 Industrial Park Wakefield',
#   'PAIR': 'Yorkshire Purchasing Organisation with Specialists Crafts Limited',
#   'CPV_DIVISION': '19'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74ecc1'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Yorkshire Purchasing Organisation',
#   'CAE_ADDRESS': '41 Industrial Park',
#   'CAE_TOWN': 'Wakefield',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 6722053.06,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Velcro Limited',
#   'nCPV': 19200000,
#   'CPV': '19200000',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 8, 0, 0),
#   'ADDRESS': '41 Industrial Park Wakefield',
#   'PAIR': 'Yorkshire Purchasing Organisation with Velcro Limited',
#   'CPV_DIVISION': '19'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74ecc2'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Yorkshire Purchasing Organisation',
#   'CAE_ADDRESS': '41 Industrial Park',
#   'CAE_TOWN': 'Wakefield',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 477944.61,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Cicada Educational Equipment Ltd',
#   'nCPV': 39221170,
#   'CPV': '39221170',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 8, 0, 0),
#   'ADDRESS': '41 Industrial Park Wakefield',
#   'PAIR': 'Yorkshire Purchasing Organisation with Cicada Educational Equipment Ltd',
#   'CPV_DIVISION': '39'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74ecc3'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Yorkshire Purchasing Organisation',
#   'CAE_ADDRESS': '41 Industrial Park',
#   'CAE_TOWN': 'Wakefield',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 477944.61,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Craven & Co Ltd',
#   'nCPV': 39221170,
#   'CPV': '39221170',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 8, 0, 0),
#   'ADDRESS': '41 Industrial Park Wakefield',
#   'PAIR': 'Yorkshire Purchasing Organisation with Craven & Co Ltd',
#   'CPV_DIVISION': '39'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74ecc4'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Yorkshire Purchasing Organisation',
#   'CAE_ADDRESS': '41 Industrial Park',
#   'CAE_TOWN': 'Wakefield',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 477944.61,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'D&G Educational Ltd',
#   'nCPV': 39221170,
#   'CPV': '39221170',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 8, 0, 0),
#   'ADDRESS': '41 Industrial Park Wakefield',
#   'PAIR': 'Yorkshire Purchasing Organisation with D&G Educational Ltd',
#   'CPV_DIVISION': '39'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74ecc6'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Yorkshire Purchasing Organisation',
#   'CAE_ADDRESS': '41 Industrial Park',
#   'CAE_TOWN': 'Wakefield',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 6722053.06,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Spotless Punch Limited',
#   'nCPV': 19200000,
#   'CPV': '19200000',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 8, 0, 0),
#   'ADDRESS': '41 Industrial Park Wakefield',
#   'PAIR': 'Yorkshire Purchasing Organisation with Spotless Punch Limited',
#   'CPV_DIVISION': '19'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74ecc8'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Yorkshire Purchasing Organisation',
#   'CAE_ADDRESS': '41 Industrial Park',
#   'CAE_TOWN': 'Wakefield',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 6722053.06,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Vivelle (UK) Limited',
#   'nCPV': 19200000,
#   'CPV': '19200000',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 8, 0, 0),
#   'ADDRESS': '41 Industrial Park Wakefield',
#   'PAIR': 'Yorkshire Purchasing Organisation with Vivelle (UK) Limited',
#   'CPV_DIVISION': '19'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74ecc9'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Yorkshire Purchasing Organisation',
#   'CAE_ADDRESS': '41 Industrial Park',
#   'CAE_TOWN': 'Wakefield',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 6722053.06,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Victoria Grant',
#   'nCPV': 19200000,
#   'CPV': '19200000',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2010, 1, 8, 0, 0),
#   'ADDRESS': '41 Industrial Park Wakefield',
#   'PAIR': 'Yorkshire Purchasing Organisation with Victoria Grant',
#   'CPV_DIVISION': '19'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74ee93'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Sunderland City Council',
#   'CAE_ADDRESS': 'Corporate Procurement, PO Box 106, Civic Centre, Burden Road',
#   'CAE_TOWN': 'Sunderland',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 158766.2,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Blackpool Design Associates',
#   'NUMBER_OFFERS': 11,
#   'AWARD_VALUE_EURO': 158766.2,
#   'nCPV': 34121000,
#   'CPV': '34121000',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 7, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 10, 1, 0, 0),
#   'ADDRESS': 'Corporate Procurement, PO Box 106, Civic Centre, Burden Road Sunderland',
#   'PAIR': 'Sunderland City Council with Blackpool Design Associates',
#   'CPV_DIVISION': '34'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74eeca'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Maritime Equipment Systems, DE&S',
#   'CAE_ADDRESS': 'MES -CmrclDel1, Birch 3b, Mail Point 3327, MOD Abbey Wood South',
#   'CAE_TOWN': 'Bristol',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 1077123.94,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Burdens Ltd',
#   'NUMBER_OFFERS': 2,
#   'AWARD_VALUE_EURO': 1077123.94,
#   'nCPV': 45222100,
#   'CPV': '45222100',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 7, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 12, 30, 0, 0),
#   'ADDRESS': 'MES -CmrclDel1, Birch 3b, Mail Point 3327, MOD Abbey Wood South Bristol',
#   'PAIR': 'Maritime Equipment Systems, DE&S with Burdens Ltd',
#   'CPV_DIVISION': '45'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74ef3b'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Leicestershire County Council',
#   'CAE_ADDRESS': 'Department of Highways, Transportation and Waste Management, County Hall, Leicester Road, Glenfield',
#   'CAE_TOWN': 'Leicester',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 138149.31,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Paul S Winson Coaches Limited',
#   'NUMBER_OFFERS': 8,
#   'nCPV': 60100000,
#   'CPV': '60100000',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 6, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 12, 23, 0, 0),
#   'ADDRESS': 'Department of Highways, Transportation and Waste Management, County Hall, Leicester Road, Glenfield Leicester',
#   'PAIR': 'Leicestershire County Council with Paul S Winson Coaches Limited',
#   'CPV_DIVISION': '60'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74ef41'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Leicestershire County Council',
#   'CAE_ADDRESS': 'Department of Highways, Transportation and Waste Management, County Hall, Leicester Road, Glenfield',
#   'CAE_TOWN': 'Leicester',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 163666.88,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'Paul James Coaches Limited',
#   'NUMBER_OFFERS': 4,
#   'nCPV': 60100000,
#   'CPV': '60100000',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 6, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 12, 23, 0, 0),
#   'ADDRESS': 'Department of Highways, Transportation and Waste Management, County Hall, Leicester Road, Glenfield Leicester',
#   'PAIR': 'Leicestershire County Council with Paul James Coaches Limited',
#   'CPV_DIVISION': '60'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74ef47'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Newcastle City Council',
#   'CAE_ADDRESS': 'Newcastle Civic Centre, Corporate Business Management Room 205',
#   'CAE_TOWN': 'Newcastle Upon Tyne',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 1165718.55,
#   'B_EU_FUNDS': 'Y',
#   'WIN_NAME': 'King Sturge LLP',
#   'NUMBER_OFFERS': 3,
#   'nCPV': 45111291,
#   'CPV': '45111291',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 6, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 9, 1, 0, 0),
#   'ADDRESS': 'Newcastle Civic Centre, Corporate Business Management Room 205 Newcastle Upon Tyne',
#   'PAIR': 'Newcastle City Council with King Sturge LLP',
#   'CPV_DIVISION': '45'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74ef48'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Newcastle City Council',
#   'CAE_ADDRESS': 'Newcastle Civic Centre, Corporate Business Management Room 205',
#   'CAE_TOWN': 'Newcastle Upon Tyne',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 1165718.55,
#   'B_EU_FUNDS': 'Y',
#   'WIN_NAME': 'Make Architects Ltd',
#   'NUMBER_OFFERS': 5,
#   'nCPV': 45111291,
#   'CPV': '45111291',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 6, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 9, 1, 0, 0),
#   'ADDRESS': 'Newcastle Civic Centre, Corporate Business Management Room 205 Newcastle Upon Tyne',
#   'PAIR': 'Newcastle City Council with Make Architects Ltd',
#   'CPV_DIVISION': '45'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74ef77'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Buckinghamshire County Council',
#   'CAE_ADDRESS': 'County Hall',
#   'CAE_TOWN': 'Aylesbury',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 1095775.44,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'ASM Metal Recycling Ltd',
#   'NUMBER_OFFERS': 5,
#   'AWARD_VALUE_EURO': 1095775.44,
#   'nCPV': 90000000,
#   'CPV': '90000000',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 6, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 11, 13, 0, 0),
#   'ADDRESS': 'County Hall Aylesbury',
#   'PAIR': 'Buckinghamshire County Council with ASM Metal Recycling Ltd',
#   'CPV_DIVISION': '90'},
#  {'_id': ObjectId('5ef10f728c20d9f6af74f023'),
#   'YEAR': 2010,
#   'CAE_NAME': 'Lewisham College',
#   'CAE_ADDRESS': 'Lewisham Way',
#   'CAE_TOWN': 'London',
#   'ISO_COUNTRY_CODE': 'GB',
#   'VALUE_EURO': 1336784.25,
#   'B_EU_FUNDS': 'N',
#   'WIN_NAME': 'The Lewis & Graves Partnership',
#   'NUMBER_OFFERS': 12,
#   'AWARD_VALUE_EURO': 1336784.25,
#   'nCPV': 90911200,
#   'CPV': '90911200',
#   'DT_DISPATCH': datetime.datetime(2010, 1, 7, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 12, 3, 0, 0),
#   'ADDRESS': 'Lewisham Way London',
#   'PAIR': 'Lewisham College with The Lewis & Graves Partnership',
#   'CPV_DIVISION': '90'},
#  ...]
